# %%
# !pip install contractions
# !pip install datasets
# Out:
# Requirement already satisfied: contractions in /usr/local/lib/python3.10/dist-packages (0.1.73)
# Requirement already satisfied: textsearch>=0.0.21 in /usr/local/lib/python3.10/dist-packages (from contractions) (0.0.24)
# Requirement already satisfied: anyascii in /usr/local/lib/python3.10/dist-packages (from textsearch>=0.0.21->contractions) (0.3.2)
# Requirement already satisfied: pyahocorasick in /usr/local/lib/python3.10/dist-packages (from textsearch>=0.0.21->contractions) (2.1.0)
# Collecting datasets
#   Downloading datasets-3.0.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.16.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.26.4)
# Collecting pyarrow>=15.0.0 (from datasets)
#   Downloading pyarrow-17.0.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (3.3 kB)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.1.4)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.5)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: fsspec<=2024.6.1,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<=2024.6.1,>=2023.1.0->datasets) (2024.6.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.10.5)
# Requirement already satisfied: huggingface-hub>=0.22.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.24.7)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.11.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.22.0->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2024.8.30)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Downloading datasets-3.0.0-py3-none-any.whl (474 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 474.3/474.3 kB 8.1 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 7.0 MB/s eta 0:00:00
# Downloading pyarrow-17.0.0-cp310-cp310-manylinux_2_28_x86_64.whl (39.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.9/39.9 MB 16.6 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 7.7 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 8.7 MB/s eta 0:00:00
# Installing collected packages: xxhash, pyarrow, dill, multiprocess, datasets
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 14.0.2
#     Uninstalling pyarrow-14.0.2:
#       Successfully uninstalled pyarrow-14.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 24.4.1 requires pyarrow<15.0.0a0,>=14.0.1, but you have pyarrow 17.0.0 which is incompatible.
# ibis-framework 8.0.0 requires pyarrow<16,>=2, but you have pyarrow 17.0.0 which is incompatible.
# Successfully installed datasets-3.0.0 dill-0.3.8 multiprocess-0.70.16 pyarrow-17.0.0 xxhash-3.5.0

# %%
import numpy as np
import pandas as pd

import re
import string # for text cleaning
import contractions # for expanding short form words
from tqdm import tqdm
tqdm.pandas(desc="Progress Bar")

import torch
from datasets import load_dataset
from transformers import DistilBertTokenizer, DistilBertModel
from sklearn.metrics.pairwise import cosine_similarity

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Load Resume Data

# %%
df = pd.read_csv('/content/drive/MyDrive/CV-JD-Matching/pdf_extracted_skills_education.csv')
df.head()
# Out:
#                                               Skills  \
# 0  Accounting; General Accounting; Accounts Payab...
# 1  accounting, accounts payable, Accounts Receiva...
# 2  accounts payables, accounts receivables, Accou...
# 3  accounting, balance sheet, budgets, client, cl...
# 4                    Aderant/CMS Financial reporting
#
#                                            Education        ID    Category
# 0  Northern Maine Community College 1994 Associat...  10554236  ACCOUNTANT
# 1  Bachelor of Science : Accounting , May 2010 Un...  10674770  ACCOUNTANT
# 2  Computer Applications Specialist Certificate P...  11163645  ACCOUNTANT
# 3  EMORY UNIVERSITY, Goizueta Business School 5 2...  11759079  ACCOUNTANT
# 4  Bachelor of Business Administration : Accounti...  12065211  ACCOUNTANT

# %%
df.shape
# Out:
# (2484, 4)

# %% [markdown]
# ## Loading JD Data

# %%
jd_data = load_dataset('jacob-hugging-face/job-descriptions', split="train")
jd_data
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md:   0%|          | 0.00/24.0 [00:00<?, ?B/s]
# training_data.csv:   0%|          | 0.00/3.77M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/853 [00:00<?, ? examples/s]
# Dataset({
#     features: ['company_name', 'job_description', 'position_title', 'description_length', 'model_response'],
#     num_rows: 853
# })

# %%
jd_df = pd.DataFrame(jd_data)
jd_df.head()
# Out:
#   company_name                                    job_description  \
# 0       Google  minimum qualifications\nbachelors degree or eq...
# 1        Apple  description\nas an asc you will be highly infl...
# 2      Netflix  its an amazing time to be joining netflix as w...
# 3  Robert Half  description\n\nweb designers looking to expand...
# 4    TrackFive  at trackfive weve got big goals were on a miss...
#
#                               position_title  description_length  \
# 0                           Sales Specialist                2727
# 1                 Apple Solutions Consultant                 828
# 2  Licensing Coordinator - Consumer Products                3205
# 3                               Web Designer                2489
# 4                              Web Developer                3167
#
#                                       model_response
# 0   {\n  "Core Responsibilities": "Responsible fo...
# 1   {\n  "Core Responsibilities": "as an asc you ...
# 2   {\n  "Core Responsibilities": "Help drive bus...
# 3   {\n  "Core Responsibilities": "Designing webs...
# 4   {\n  "Core Responsibilities": "Build and layo...

# %%
print(jd_df['job_description'][0])
print(jd_df['model_response'][0])
# Out:
# minimum qualifications
# bachelors degree or equivalent practical experience years of experience in saas or productivity tools businessexperience managing enterprise accounts with sales cycles
# preferred qualifications
#  years of experience building strategic business partnerships with enterprise customersability to work through and with a reseller ecosystem to scale the businessability to plan pitch and execute a territory business strategyability to build relationships and to deliver results in a crossfunctionalmatrixed environmentability to identify crosspromoting and uppromoting opportunities within the existing account baseexcellent account management writtenverbal communication strategic and analyticalthinking skills
# about the job
# as a member of the google cloud team you inspire leading companies schools and government agencies to work smarter with google tools like google workspace search and chrome you advocate the innovative power of our products to make organizations more productive collaborative and mobile your guiding light is doing whats right for the customer you will meet customers exactly where they are at and provide them the best solutions for innovation using your passion for google products you help spread the magic of google to organizations around the world
# the google workspace team helps customers transform and evolve their business through the use of googles productivity collaboration and content management suite of applications as part of an entrepreneurial team in this growing business you will help shape the future of businesses use technology to connect with customers employees and partners
# as a google workspace sales specialist you will be responsible for maintenance and expansion of google workspace business growth across the region with customers in this role youll create and execute the strategy and provide unique insights on applying google workspace solutions to enterprisesyou will build an excellent pipeline and work with the account teams to build out the customer solution and establish partnerships you will strategize with partners to increase account and territory business growth you will work directly with customers coordinate internal resources and construct successful strategies at account and territory level
# google cloud accelerates organizations ability to digitally transform their business with the best infrastructure platform industry solutions and expertise we deliver enterprisegrade solutions that leverage googles cuttingedge technology  all on the cleanest cloud in the industry customers in more than  countries and territories turn to google cloud as their trusted partner to enable growth and solve their most critical business problems
#  {
#   "Core Responsibilities": "Responsible for expanding Google Workspace product adoption across an assigned territory. Build relationships with customers to understand needs and provide Google Workspace solutions. Partner with account teams to construct solutions and grow business for Google Workspace.",
#   "Required Skills": "Bachelor's degree or equivalent experience. Experience managing enterprise SaaS accounts and sales cycles.",
#   "Educational Requirements": "Bachelor's degree or equivalent experience.",
#   "Experience Level": "Experience managing enterprise SaaS accounts and sales cycles.",
#   "Preferred Qualifications": "Experience building strategic partnerships with enterprise customers. Ability to work through a reseller ecosystem. Excellent communication and strategic thinking skills.",
#   "Compensation and Benefits": "N/A"
# }

# %% [markdown]
# ## Basic text cleaning
#
# And doing some preprocessing in the data as discussed in the EDA notebook

# %%
def text_cleaning(text:str) -> str:
    if pd.isnull(text):
        return
    text = text.lower().strip()
    translator = str.maketrans('', '', string.punctuation)
    text = contractions.fix(text)
    text = re.sub(r'http\S+|www\S+|https\S+', '', text) # Remove URLs
    text = re.sub(r'\S+@\S+', '', text) # Remove emails
    text = re.sub(r'\b\d{1,3}[-./]?\d{1,3}[-./]?\d{1,4}\b', '', text) # Remove phone numbers
    text = text.translate(translator) # Remove puctuations
    text = re.sub(r'[^a-zA-Z]', ' ', text) # Remove other non-alphanumeric characters

    return text.strip()

# %%
cv_df = df[~(df['Skills'].isna() & df['Education'].isna())].reset_index(drop=True)
cv_df = cv_df.fillna(value='')
cv_df['CV'] = cv_df['Skills'] + ' ' + cv_df['Education']
cv_df['CV'] = cv_df['CV'].progress_apply(text_cleaning)
# Out:
# Progress Bar: 100%|██████████| 2469/2469 [00:00<00:00, 5591.07it/s]

# %%
cv_df.shape
# Out:
# (2469, 5)

# %%
job_descriptions = jd_df['job_description'].apply(text_cleaning)[:15].to_list() # jd_df['job_description'][:15]
resumes = cv_df['CV'].to_list()

# %%
print(resumes[0])
# Out:
# accounting general accounting accounts payable program management northern maine community college  associate  accounting city  state  usa emphasis in business  associates  accounting city  state  usa gpa gpa  accounting gpa   hours quarter attended husson college major accounting    semester hours toward bachelors degree professional military comptroller school  wk  managerial accounting i  interestedbased bargaining training for management   hrs  auditing methods and concepts  organizational leadership   hrs  management development ii   hrs

# %%
print(job_descriptions[0])
# Out:
# minimum qualifications bachelors degree or equivalent practical experience years of experience in saas or productivity tools businessexperience managing enterprise accounts with sales cycles preferred qualifications  years of experience building strategic business partnerships with enterprise customersability to work through and with a reseller ecosystem to scale the businessability to plan pitch and execute a territory business strategyability to build relationships and to deliver results in a crossfunctionalmatrixed environmentability to identify crosspromoting and uppromoting opportunities within the existing account baseexcellent account management writtenverbal communication strategic and analyticalthinking skills about the job as a member of the google cloud team you inspire leading companies schools and government agencies to work smarter with google tools like google workspace search and chrome you advocate the innovative power of our products to make organizations more productive collaborative and mobile your guiding light is doing what is right for the customer you will meet customers exactly where they are at and provide them the best solutions for innovation using your passion for google products you help spread the magic of google to organizations around the world the google workspace team helps customers transform and evolve their business through the use of googles productivity collaboration and content management suite of applications as part of an entrepreneurial team in this growing business you will help shape the future of businesses use technology to connect with customers employees and partners as a google workspace sales specialist you will be responsible for maintenance and expansion of google workspace business growth across the region with customers in this role you will create and execute the strategy and provide unique insights on applying google workspace solutions to enterprisesyou will build an excellent pipeline and work with the account teams to build out the customer solution and establish partnerships you will strategize with partners to increase account and territory business growth you will work directly with customers coordinate internal resources and construct successful strategies at account and territory level google cloud accelerates organizations ability to digitally transform their business with the best infrastructure platform industry solutions and expertise we deliver enterprisegrade solutions that leverage googles cuttingedge technology  all on the cleanest cloud in the industry customers in more than  countries and territories turn to google cloud as their trusted partner to enable growth and solve their most critical business problems

# %% [markdown]
# ## Creating Embedding using `DistilBertTokenizer`, `DistilBertModel`

# %%
# %%time

# Initialize the DistilBERT tokenizer and model
tokenizer = DistilBertTokenizer.from_pretrained('distilbert-base-uncased')
model = DistilBertModel.from_pretrained('distilbert-base-uncased')


# Tokenize and embed job descriptions
job_description_embeddings = []
for description in job_descriptions:
    tokens = tokenizer(description, padding=True, truncation=True, return_tensors='pt')
    with torch.no_grad():
        output = model(**tokens)
    embeddings = output.last_hidden_state.mean(dim=1).numpy()
    job_description_embeddings.append(embeddings[0])  # Flatten the embeddings to 1D
# Out:
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/483 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# CPU times: user 17.7 s, sys: 3.34 s, total: 21 s
# Wall time: 33.3 s

# %%
# Tokenize and embed resumes
resume_embeddings = []
for resume in resumes:
    tokens = tokenizer(resume, padding=True, truncation=True, return_tensors='pt')
    with torch.no_grad():
        output = model(**tokens)
    embeddings = output.last_hidden_state.mean(dim=1).numpy()
    resume_embeddings.append(embeddings[0])

# %%
save_directory = '/content/drive/MyDrive/distilbert_model'

# Save the model and tokenizer
model.save_pretrained(save_directory)
tokenizer.save_pretrained(save_directory)
# Out:
# ('/content/drive/MyDrive/distilbert_model/tokenizer_config.json',
#  '/content/drive/MyDrive/distilbert_model/special_tokens_map.json',
#  '/content/drive/MyDrive/distilbert_model/vocab.txt',
#  '/content/drive/MyDrive/distilbert_model/added_tokens.json')

# %%
job_description_embeddings[0].shape, resume_embeddings[0].shape
# Out:
# ((768,), (768,))

# %%
len(job_description_embeddings), len(resume_embeddings)
# Out:
# (15, 2469)

# %% [markdown]
# ## Calculating Similarity Score & Getting Top n Candidates

# %%
# Calculate cosine similarity between job descriptions and resumes
similarity_scores = cosine_similarity(job_description_embeddings, resume_embeddings)
similarity_scores
# Out:
# array([[0.82088774, 0.77677274, 0.7848917 , ..., 0.8589794 , 0.7705459 ,
#         0.60554785],
#        [0.7844252 , 0.7171359 , 0.7481307 , ..., 0.8324866 , 0.7884388 ,
#         0.6784491 ],
#        [0.81398576, 0.7895926 , 0.78363687, ..., 0.84983325, 0.7580299 ,
#         0.6202629 ],
#        ...,
#        [0.81677645, 0.7708843 , 0.7748317 , ..., 0.884326  , 0.7708575 ,
#         0.6345933 ],
#        [0.8439074 , 0.77827585, 0.7971461 , ..., 0.87831897, 0.82519805,
#         0.68138146],
#        [0.83300304, 0.7873483 , 0.77523583, ..., 0.88907975, 0.7842255 ,
#         0.64485663]], dtype=float32)

# %%
# Rank job descriptions for each candidate based on similarity scores
num_top_jobs = 10
top_jobs_for_candidates = []

for candidate_index in range(len(resumes)):
    job_scores = list(enumerate(similarity_scores[:, candidate_index]))
    job_scores.sort(key=lambda x: x[1], reverse=True)
    top_jobs_for_candidate = job_scores[:num_top_jobs]
    top_jobs_for_candidates.append(top_jobs_for_candidate)

# Print the top job descriptions for each candidate
for candidate_index in range(len(resumes)):
    candidate_id = cv_df['ID'][candidate_index]
    candidate_category = cv_df['Category'][candidate_index]

    print(f"\n==============================")
    print(f"Top {num_top_jobs} Job Matches for Candidate {candidate_index + 1}")
    print(f"Candidate ID: {candidate_id}, Category: {candidate_category}")
    print("==============================\n")

    for rank, (job_index, score) in enumerate(top_jobs_for_candidates[candidate_index], start=1):
        job_title = jd_df['position_title'][job_index]
        print(f"{rank}. Job Title: {job_title}")
        print(f"   Job ID: {job_index + 1}")
        print(f"   Similarity Score: {score:.4f}\n")
# Out:
# Streaming output truncated to the last 5000 lines.
# 3. Job Title: Web Designer
#    Job ID: 8
#    Similarity Score: 0.9012
#
# 4. Job Title: Frontend Web Developer
#    Job ID: 6
#    Similarity Score: 0.8995
#
# 5. Job Title: Web Developer
#    Job ID: 12
#    Similarity Score: 0.8945
#
# 6. Job Title: UI Web Designer
#    Job ID: 15
#    Similarity Score: 0.8944
#
# 7. Job Title: Web Developer
#    Job ID: 11
#    Similarity Score: 0.8936
#
# 8. Job Title: Licensing Coordinator - Consumer Products
#    Job ID: 3
#    Similarity Score: 0.8885
#
# 9. Job Title: SR. Web Designer
#    Job ID: 10
#    Similarity Score: 0.8859
#
# 10. Job Title: Senior UI Designer
#    Job ID: 13
#    Similarity Score: 0.8815
#
#
# ==============================
# Top 10 Job Matches for Candidate 2362
# Candidate ID: 85918100, Category: SALES
# ==============================
#
# 1. Job Title: Web Developer
#    Job ID: 11
#    Similarity Score: 0.8378
#
# 2. Job Title: Web Designer
#    Job ID: 4
#    Similarity Score: 0.8322
#
# 3. Job Title: Wordpress Web Developer
#    Job ID: 14
#    Similarity Score: 0.8215
#
# 4. Job Title: Web Designer
#    Job ID: 8
#    Similarity Score: 0.8199
#
# 5. Job Title: SR. Web Designer
#    Job ID: 10
#    Similarity Score: 0.8193
#
# 6. Job Title: Remote Website Designer
#    Job ID: 7
#    Similarity Score: 0.8179
#
# 7. Job Title: Web Developer
#    Job ID: 5
#    Similarity Score: 0.8168
#
# 8. Job Title: Web Developer
#    Job ID: 12
#    Similarity Score: 0.8150
#
# 9. Job Title: Web Designer
#    Job ID: 9
#    Similarity Score: 0.8133
#
# 10. Job Title: UI Web Designer
#    Job ID: 15
#    Similarity Score: 0.8091
#
#
# ==============================
# Top 10 Job Matches for Candidate 2363
# Candidate ID: 87118391, Category: SALES
# ==============================
#
# 1. Job Title: Web Designer
#    Job ID: 8
#    Similarity Score: 0.8718
#
# 2. Job Title: SR. Web Designer
#    Job ID: 10
#    Similarity Score: 0.8669
#
# 3. Job Title: UI Web Designer
#    Job ID: 15
#    Similarity Score: 0.8613
#
# 4. Job Title: Web Designer
#    Job ID: 4
#    Similarity Score: 0.8598
#
# 5. Job Title: Web Developer
#    Job ID: 11
#    Similarity Score: 0.8531
#
# 6. Job Title: Web Developer
#    Job ID: 12
#    Similarity Score: 0.8504
#
# 7. Job Title: Senior UI Designer
#    Job ID: 13
#    Similarity Score: 0.8496
#
# 8. Job Title: Web Developer
#    Job ID: 5
#    Similarity Score: 0.8476
#
# 9. Job Title: Remote Website Designer
#    Job ID: 7
#    Similarity Score: 0.8459
#
# 10. Job Title: Licensing Coordinator - Consumer Products
#    Job ID: 3
#    Similarity Score: 0.8450
#
#
# ==============================
# Top 10 Job Matches for Candidate 2364
# Candidate ID: 90682785, Category: SALES
# ==============================
#
# 1. Job Title: Wordpress Web Developer
#    Job ID: 14
#    Similarity Score: 0.8108
#
# 2. Job Title: Web Designer
#    Job ID: 4
#    Similarity Score: 0.7962
#
# 3. Job Title: Frontend Web Developer
#    Job ID: 6
#    Similarity Score: 0.7903
#
# 4. Job Title: Web Developer
#    Job ID: 12
#    Similarity Score: 0.7844
#
# 5. Job Title: Web Developer
#    Job ID: 11
#    Similarity Score: 0.7843
#
# 6. Job Title: Web Designer
#    Job ID: 9
#    Similarity Score: 0.7809
#
# 7. Job Title: Web Developer
#    Job ID: 5
#    Similarity Score: 0.7796
#
# 8. Job Title: Sales Specialist
#    Job ID: 1
#    Similarity Score: 0.7764
#
# 9. Job Title: Apple Solutions Consultant
#    Job ID: 2
#    Similarity Score: 0.7757
#
# 10. Job Title: Web Designer
#    Job ID: 8
#    Similarity Score: 0.7746
#
#
# ==============================
# Top 10 Job Matches for Candidate 2365
# Candidate ID: 92200491, Category: SALES
# ==============================
#
# 1. Job Title: Web Designer
#    Job ID: 4
#    Similarity Score: 0.8530
#
# 2. Job Title: Web Designer
#    Job ID: 8
#    Similarity Score: 0.8479
#
# 3. Job Title: Web Developer
#    Job ID: 11
#    Similarity Score: 0.8477
#
# 4. Job Title: Web Developer
#    Job ID: 5
#    Similarity Score: 0.8471
#
# 5. Job Title: Frontend Web Developer
#    Job ID: 6
#    Similarity Score: 0.8433
#
# 6. Job Title: Wordpress Web Developer
#    Job ID: 14
#    Similarity Score: 0.8424
#
# 7. Job Title: Web Developer
#    Job ID: 12
#    Similarity Score: 0.8410
#
# 8. Job Title: UI Web Designer
#    Job ID: 15
#    Similarity Score: 0.8390
#
# 9. Job Title: Licensing Coordinator - Consumer Products
#    Job ID: 3
#    Similarity Score: 0.8345
#
# 10. Job Title: SR. Web Designer
#    Job ID: 10
#    Similarity Score: 0.8335
#
#
# ==============================
# Top 10 Job Matches for Candidate 2366
# Candidate ID: 98108571, Category: SALES
# ==============================
#
# 1. Job Title: Wordpress Web Developer
#    Job ID: 14
#    Similarity Score: 0.6866
#
# 2. Job Title: Frontend Web Developer
#    Job ID: 6
#    Similarity Score: 0.6385
#
# 3. Job Title: Web Designer
#    Job ID: 9
#    Similarity Score: 0.5985
#
# 4. Job Title: UI Web Designer
#    Job ID: 15
#    Similarity Score: 0.5967
#
# 5. Job Title: Apple Solutions Consultant
#    Job ID: 2
#    Similarity Score: 0.5961
#
# 6. Job Title: Web Developer
#    Job ID: 5
#    Similarity Score: 0.5950
#
# 7. Job Title: Senior UI Designer
#    Job ID: 13
#    Similarity Score: 0.5934
#
# 8. Job Title: Web Designer
#    Job ID: 4
#    Similarity Score: 0.5912
#
# 9. Job Title: Web Designer
#    Job ID: 8
#    Similarity Score: 0.5856
#
# 10. Job Title: Web Developer
#    Job ID: 11
#    Similarity Score: 0.5790
#
#
# ==============================
# Top 10 Job Matches for Candidate 2367
# Candidate ID: 98509238, Category: SALES
# ==============================
#
# 1. Job Title: Wordpress Web Developer
#    Job ID: 14
#    Similarity Score: 0.8017
#
# 2. Job Title: Frontend Web Developer
#    Job ID: 6
#    Similarity Score: 0.7569
#
# 3. Job Title: Web Designer
#    Job ID: 4
#    Similarity Score: 0.7500
#
# 4. Job Title: Web Designer
#    Job ID: 8
#    Similarity Score: 0.7476
#
# 5. Job Title: Web Developer
#    Job ID: 5
#    Similarity Score: 0.7450
#
# 6. Job Title: Sales Specialist
#    Job ID: 1
#    Similarity Score: 0.7448
#
# 7. Job Title: Apple Solutions Consultant
#    Job ID: 2
#    Similarity Score: 0.7377
#
# 8. Job Title: Web Developer
#    Job ID: 12
#    Similarity Score: 0.7340
#
# 9. Job Title: Web Developer
#    Job ID: 11
#    Similarity Score: 0.7300
#
# 10. Job Title: Web Designer
#    Job ID: 9
#    Similarity Score: 0.7295
#
#
# ==============================
# Top 10 Job Matches for Candidate 2368
# Candidate ID: 10504237, Category: TEACHER
# ==============================
#
# 1. Job Title: SR. Web Designer
#    Job ID: 10
#    Similarity Score: 0.8918
#
# 2. Job Title: Web Developer
#    Job ID: 11
#    Similarity Score: 0.8807
#
# 3. Job Title: UI Web Designer
#    Job ID: 15
#    Similarity Score: 0.8767
#
# 4. Job Title: Web Developer
#    Job ID: 5
#    Similarity Score: 0.8765
#
# 5. Job Title: Web Designer
#    Job ID: 4
#    Similarity Score: 0.8748
#
# 6. Job Title: Web Designer
#    Job ID: 8
#    Similarity Score: 0.8735
#
# 7. Job Title: Web Developer
#    Job ID: 12
#    Similarity Score: 0.8653
#
# 8. Job Title: Remote Website Designer
#    Job ID: 7
#    Similarity Score: 0.8632
#
# 9. Job Title: Senior UI Designer
#    Job ID: 13
#    Similarity Score: 0.8589
#
# 10. Job Title: Web Designer
#    Job ID: 9
#    Similarity Score: 0.8585
#
#
# ==============================
# Top 10 Job Matches for Candidate 2369
# Candidate ID: 10527994, Category: TEACHER
# ==============================
#
# 1. Job Title: Wordpress Web Developer
#    Job ID: 14
#    Similarity Score: 0.7521
#
# 2. Job Title: Frontend Web Developer
#    Job ID: 6
#    Similarity Score: 0.6621
#
# 3. Job Title: Web Developer
#    Job ID: 5
#    Similarity Score: 0.6485
#
# 4. Job Title: Web Designer
#    Job ID: 4
#    Similarity Score: 0.6392
#
# 5. Job Title: Apple Solutions Consultant
#    Job ID: 2
#    Similarity Score: 0.6383
#
# 6. Job Title: Web Designer
#    Job ID: 9
#    Similarity Score: 0.6375
#
# 7. Job Title: Web Developer
#    Job ID: 12
#    Similarity Score: 0.6360
#
# 8. Job Title: Web Developer
#    Job ID: 11
#    Similarity Score: 0.6332
#
# 9. Job Title: UI Web Designer
#    Job ID: 15
#    Similarity Score: 0.6272
#
# 10. Job Title: Web Designer
#    Job ID: 8
#    Similarity Score: 0.6246
#
#
# ==============================
# Top 10 Job Matches for Candidate 2370
# Candidate ID: 10909720, Category: TEACHER
# ==============================
#
# 1. Job Title: Frontend Web Developer
#    Job ID: 6
#    Similarity Score: 0.8688
#
# 2. Job Title: Web Designer
#    Job ID: 8
#    Similarity Score: 0.8646
#
# 3. Job Title: Web Developer
#    Job ID: 12
#    Similarity Score: 0.8621
#
# 4. Job Title: Web Developer
#    Job ID: 5
#    Similarity Score: 0.8565
#
# 5. Job Title: Web Designer
#    Job ID: 4
#    Similarity Score: 0.8559
#
# 6. Job Title: Wordpress Web Developer
#    Job ID: 14
#    Similarity Score: 0.8529
#
# 7. Job Title: UI Web Designer
#    Job ID: 15
#    Similarity Score: 0.8526
#
# 8. Job Title: SR. Web Designer
#    Job ID: 10
#    Similarity Score: 0.8494
#
# 9. Job Title: Apple Solutions Consultant
#    Job ID: 2
#    Similarity Score: 0.8480
#
# 10. Job Title: Senior UI Designer
#    Job ID: 13
#    Similarity Score: 0.8422
#
#
# ==============================
# Top 10 Job Matches for Candidate 2371
# Candidate ID: 11336022, Category: TEACHER
# ==============================
#
# 1. Job Title: Wordpress Web Developer
#    Job ID: 14
#    Similarity Score: 0.8434
#
# 2. Job Title: Web Designer
#    Job ID: 4
#    Similarity Score: 0.8388
#
# 3. Job Title: Frontend Web Developer
#    Job ID: 6
#    Similarity Score: 0.8246
#
# 4. Job Title: Web Developer
#    Job ID: 11
#    Similarity Score: 0.8246
#
# 5. Job Title: Web Designer
#    Job ID: 8
#    Similarity Score: 0.8208
#
# 6. Job Title: Web Developer
#    Job ID: 5
#    Similarity Score: 0.8200
#
# 7. Job Title: UI Web Designer
#    Job ID: 15
#    Similarity Score: 0.8097
#
# 8. Job Title: Web Developer
#    Job ID: 12
#    Similarity Score: 0.8087
#
# 9. Job Title: SR. Web Designer
#    Job ID: 10
#    Similarity Score: 0.8074
#
# 10. Job Title: Web Designer
#    Job ID: 9
#    Similarity Score: 0.8030
#
#
# ==============================
# Top 10 Job Matches for Candidate 2372
# Candidate ID: 11616482, Category: TEACHER
# ==============================
#
# 1. Job Title: Wordpress Web Developer
#    Job ID: 14
#    Similarity Score: 0.8520
#
# 2. Job Title: Web Designer
#    Job ID: 4
#    Similarity Score: 0.8310
#
# 3. Job Title: Web Developer
#    Job ID: 12
#    Similarity Score: 0.8297
#
# 4. Job Title: Sales Specialist
#    Job ID: 1
#    Similarity Score: 0.8238
#
# 5. Job Title: Web Developer
#    Job ID: 5
#    Similarity Score: 0.8228
#
# 6. Job Title: UI Web Designer
#    Job ID: 15
#    Similarity Score: 0.8223
#
# 7. Job Title: Web Designer
#    Job ID: 8
#    Similarity Score: 0.8205
#
# 8. Job Title: Web Developer
#    Job ID: 11
#    Similarity Score: 0.8203
#
# 9. Job Title: Senior UI Designer
#    Job ID: 13
#    Similarity Score: 0.8187
#
# 10. Job Title: Remote Website Designer
#    Job ID: 7
#    Similarity Score: 0.8163
#
#
# ==============================
# Top 10 Job Matches for Candidate 2373
# Candidate ID: 11943065, Category: TEACHER
# ==============================
#
# 1. Job Title: Wordpress Web Developer
#    Job ID: 14
#    Similarity Score: 0.8395
#
# 2. Job Title: Web Designer
#    Job ID: 4
#    Similarity Score: 0.8170
#
# 3. Job Title: SR. Web Designer
#    Job ID: 10
#    Similarity Score: 0.8160
#
# 4. Job Title: UI Web Designer
#    Job ID: 15
#    Similarity Score: 0.8116
#
# 5. Job Title: Web Developer
#    Job ID: 11
#    Similarity Score: 0.8086
#
# 6. Job Title: Web Developer
#    Job ID: 5
#    Similarity Score: 0.8055
#
# 7. Job Title: Web Developer
#    Job ID: 12
#    Similarity Score: 0.8051
#
# 8. Job Title: Web Designer
#    Job ID: 8
#    Similarity Score: 0.8037
#
# 9. Job Title: Frontend Web Developer
#    Job ID: 6
#    Similarity Score: 0.8016
#
# 10. Job Title: Remote Website Designer
#    Job ID: 7
#    Similarity Score: 0.7968
#
#
# ==============================
# Top 10 Job Matches for Candidate 2374
# Candidate ID: 12467531, Category: TEACHER
# ==============================
#
# 1. Job Title: Wordpress Web Developer
#    Job ID: 14
#    Similarity Score: 0.8101
#
# 2. Job Title: Web Designer
#    Job ID: 4
#    Similarity Score: 0.8081
#
# 3. Job Title: SR. Web Designer
#    Job ID: 10
#    Similarity Score: 0.7951
#
# 4. Job Title: Frontend Web Developer
#    Job ID: 6
#    Similarity Score: 0.7943
#
# 5. Job Title: UI Web Designer
#    Job ID: 15
#    Similarity Score: 0.7936
#
# 6. Job Title: Senior UI Designer
#    Job ID: 13
#    Similarity Score: 0.7912
#
# 7. Job Title: Web Designer
#    Job ID: 8
#    Similarity Score: 0.7888
#
# 8. Job Title: Web Developer
#    Job ID: 12
#    Similarity Score: 0.7848
#
# 9. Job Title: Web Developer
#    Job ID: 5
#    Similarity Score: 0.7822
#
# 10. Job Title: Web Developer
#    Job ID: 11
#    Similarity Score: 0.7819
#
#
# ==============================
# Top 10 Job Matches for Candidate 2375
# Candidate ID: 12587973, Category: TEACHER
# ==============================
#
# 1. Job Title: Wordpress Web Developer
#    Job ID: 14
#    Similarity Score: 0.7919
#
# 2. Job Title: Apple Solutions Consultant
#    Job ID: 2
#    Similarity Score: 0.7818
#
# 3. Job Title: Frontend Web Developer
#    Job ID: 6
#    Similarity Score: 0.7720
#
# 4. Job Title: Web Designer
#    Job ID: 4
#    Similarity Score: 0.7682
#
# 5. Job Title: Web Designer
#    Job ID: 8
#    Similarity Score: 0.7647
#
# 6. Job Title: Sales Specialist
#    Job ID: 1
#    Similarity Score: 0.7609
#
# 7. Job Title: Web Developer
#    Job ID: 12
#    Similarity Score: 0.7601
#
# 8. Job Title: UI Web Designer
#    Job ID: 15
#    Similarity Score: 0.7550
#
# 9. Job Title: Web Developer
#    Job ID: 11
#    Similarity Score: 0.7523
#
# 10. Job Title: Web Developer
#    Job ID: 5
#    Similarity Score: 0.7520
#
#
# ==============================
# Top 10 Job Matches for Candidate 2376
# Candidate ID: 13087952, Category: TEACHER
# ==============================
#
# 1. Job Title: SR. Web Designer
#    Job ID: 10
#    Similarity Score: 0.7804
#
# 2. Job Title: Wordpress Web Developer
#    Job ID: 14
#    Similarity Score: 0.7764
#
# 3. Job Title: Web Designer
#    Job ID: 4
#    Similarity Score: 0.7725
#
# 4. Job Title: Web Designer
#    Job ID: 8
#    Similarity Score: 0.7621
#
# 5. Job Title: UI Web Designer
#    Job ID: 15
#    Similarity Score: 0.7595
#
# 6. Job Title: Web Developer
#    Job ID: 5
#    Similarity Score: 0.7576
#
# 7. Job Title: Web Developer
#    Job ID: 11
#    Similarity Score: 0.7555
#
# 8. Job Title: Frontend Web Developer
#    Job ID: 6
#    Similarity Score: 0.7548
#
# 9. Job Title: Web Developer
#    Job ID: 12
#    Similarity Score: 0.7470
#
# 10. Job Title: Remote Website Designer
#    Job ID: 7
#    Similarity Score: 0.7368
#
#
# ==============================
# Top 10 Job Matches for Candidate 2377
# Candidate ID: 13296856, Category: TEACHER
# ==============================
#
# 1. Job Title: Web Designer
#    Job ID: 8
#    Similarity Score: 0.8872
#
# 2. Job Title: UI Web Designer
#    Job ID: 15
#    Similarity Score: 0.8658
#
# 3. Job Title: Sales Specialist
#    Job ID: 1
#    Similarity Score: 0.8651
#
# 4. Job Title: SR. Web Designer
#    Job ID: 10
#    Similarity Score: 0.8628
#
# 5. Job Title: Senior UI Designer
#    Job ID: 13
#    Similarity Score: 0.8618
#
# 6. Job Title: Remote Website Designer
#    Job ID: 7
#    Similarity Score: 0.8617
#
# 7. Job Title: Licensing Coordinator - Consumer Products
#    Job ID: 3
#    Similarity Score: 0.8609
#
# 8. Job Title: Web Developer
#    Job ID: 12
#    Similarity Score: 0.8607
#
# 9. Job Title: Web Developer
#    Job ID: 5
#    Similarity Score: 0.8594
#
# 10. Job Title: Web Designer
#    Job ID: 4
#    Similarity Score: 0.8561
#
#
# ==============================
# Top 10 Job Matches for Candidate 2378
# Candidate ID: 13330982, Category: TEACHER
# ==============================
#
# 1. Job Title: SR. Web Designer
#    Job ID: 10
#    Similarity Score: 0.8251
#
# 2. Job Title: UI Web Designer
#    Job ID: 15
#    Similarity Score: 0.8239
#
# 3. Job Title: Web Designer
#    Job ID: 8
#    Similarity Score: 0.8208
#
# 4. Job Title: Senior UI Designer
#    Job ID: 13
#    Similarity Score: 0.8177
#
# 5. Job Title: Web Developer
#    Job ID: 12
#    Similarity Score: 0.8177
#
# 6. Job Title: Web Designer
#    Job ID: 4
#    Similarity Score: 0.8166
#
# 7. Job Title: Wordpress Web Developer
#    Job ID: 14
#    Similarity Score: 0.8158
#
# 8. Job Title: Web Developer
#    Job ID: 11
#    Similarity Score: 0.8127
#
# 9. Job Title: Frontend Web Developer
#    Job ID: 6
#    Similarity Score: 0.8043
#
# 10. Job Title: Web Developer
#    Job ID: 5
#    Similarity Score: 0.8036
#
#
# ==============================
# Top 10 Job Matches for Candidate 2379
# Candidate ID: 13583538, Category: TEACHER
# ==============================
#
# 1. Job Title: Web Designer
#    Job ID: 4
#    Similarity Score: 0.8860
#
# 2. Job Title: Web Developer
#    Job ID: 5
#    Similarity Score: 0.8845
#
# 3. Job Title: Frontend Web Developer
#    Job ID: 6
#    Similarity Score: 0.8837
#
# 4. Job Title: Web Developer
#    Job ID: 12
#    Similarity Score: 0.8794
#
# 5. Job Title: UI Web Designer
#    Job ID: 15
#    Similarity Score: 0.8778
#
# 6. Job Title: Web Designer
#    Job ID: 8
#    Similarity Score: 0.8754
#
# 7. Job Title: Sales Specialist
#    Job ID: 1
#    Similarity Score: 0.8687
#
# 8. Job Title: Senior UI Designer
#    Job ID: 13
#    Similarity Score: 0.8683
#
# 9. Job Title: Web Designer
#    Job ID: 9
#    Similarity Score: 0.8681
#
# 10. Job Title: Wordpress Web Developer
#    Job ID: 14
#    Similarity Score: 0.8566
#
#
# ==============================
# Top 10 Job Matches for Candidate 2380
# Candidate ID: 13855004, Category: TEACHER
# ==============================
#
# 1. Job Title: SR. Web Designer
#    Job ID: 10
#    Similarity Score: 0.8733
#
# 2. Job Title: Web Designer
#    Job ID: 4
#    Similarity Score: 0.8647
#
# 3. Job Title: Web Developer
#    Job ID: 11
#    Similarity Score: 0.8644
#
# 4. Job Title: Web Developer
#    Job ID: 12
#    Similarity Score: 0.8549
#
# 5. Job Title: Web Developer
#    Job ID: 5
#    Similarity Score: 0.8510
#
# 6. Job Title: Remote Website Designer
#    Job ID: 7
#    Similarity Score: 0.8509
#
# 7. Job Title: Web Designer
#    Job ID: 8
#    Similarity Score: 0.8493
#
# 8. Job Title: UI Web Designer
#    Job ID: 15
#    Similarity Score: 0.8484
#
# 9. Job Title: Web Designer
#    Job ID: 9
#    Similarity Score: 0.8419
#
# 10. Job Title: Senior UI Designer
#    Job ID: 13
#    Similarity Score: 0.8374
#
#
# ==============================
# Top 10 Job Matches for Candidate 2381
# Candidate ID: 14958913, Category: TEACHER
# ==============================
#
# 1. Job Title: Wordpress Web Developer
#    Job ID: 14
#    Similarity Score: 0.7440
#
# 2. Job Title: Frontend Web Developer
#    Job ID: 6
#    Similarity Score: 0.7060
#
# 3. Job Title: Web Designer
#    Job ID: 4
#    Similarity Score: 0.7013
#
# 4. Job Title: SR. Web Designer
#    Job ID: 10
#    Similarity Score: 0.7008
#
# 5. Job Title: Web Developer
#    Job ID: 11
#    Similarity Score: 0.6966
#
# 6. Job Title: Web Designer
#    Job ID: 8
#    Similarity Score: 0.6941
#
# 7. Job Title: Web Developer
#    Job ID: 5
#    Similarity Score: 0.6930
#
# 8. Job Title: UI Web Designer
#    Job ID: 15
#    Similarity Score: 0.6900
#
# 9. Job Title: Web Developer
#    Job ID: 12
#    Similarity Score: 0.6849
#
# 10. Job Title: Web Designer
#    Job ID: 9
#    Similarity Score: 0.6769
#
#
# ==============================
# Top 10 Job Matches for Candidate 2382
# Candidate ID: 15850434, Category: TEACHER
# ==============================
#
# 1. Job Title: Remote Website Designer
#    Job ID: 7
#    Similarity Score: 0.9473
#
# 2. Job Title: SR. Web Designer
#    Job ID: 10
#    Similarity Score: 0.9436
#
# 3. Job Title: Web Designer
#    Job ID: 8
#    Similarity Score: 0.9413
#
# 4. Job Title: UI Web Designer
#    Job ID: 15
#    Similarity Score: 0.9399
#
# 5. Job Title: Web Developer
#    Job ID: 12
#    Similarity Score: 0.9385
#
# 6. Job Title: Web Developer
#    Job ID: 11
#    Similarity Score: 0.9363
#
# 7. Job Title: Web Designer
#    Job ID: 9
#    Similarity Score: 0.9319
#
# 8. Job Title: Licensing Coordinator - Consumer Products
#    Job ID: 3
#    Similarity Score: 0.9305
#
# 9. Job Title: Senior UI Designer
#    Job ID: 13
#    Similarity Score: 0.9285
#
# 10. Job Title: Web Designer
#    Job ID: 4
#    Similarity Score: 0.9279
#
#
# ==============================
# Top 10 Job Matches for Candidate 2383
# Candidate ID: 15899269, Category: TEACHER
# ==============================
#
# 1. Job Title: Wordpress Web Developer
#    Job ID: 14
#    Similarity Score: 0.6970
#
# 2. Job Title: Web Designer
#    Job ID: 8
#    Similarity Score: 0.6561
#
# 3. Job Title: Frontend Web Developer
#    Job ID: 6
#    Similarity Score: 0.6523
#
# 4. Job Title: UI Web Designer
#    Job ID: 15
#    Similarity Score: 0.6477
#
# 5. Job Title: Apple Solutions Consultant
#    Job ID: 2
#    Similarity Score: 0.6474
#
# 6. Job Title: Remote Website Designer
#    Job ID: 7
#    Similarity Score: 0.6444
#
# 7. Job Title: Web Developer
#    Job ID: 12
#    Similarity Score: 0.6430
#
# 8. Job Title: Web Designer
#    Job ID: 4
#    Similarity Score: 0.6427
#
# 9. Job Title: SR. Web Designer
#    Job ID: 10
#    Similarity Score: 0.6425
#
# 10. Job Title: Web Designer
#    Job ID: 9
#    Similarity Score: 0.6379
#
#
# ==============================
# Top 10 Job Matches for Candidate 2384
# Candidate ID: 16210888, Category: TEACHER
# ==============================
#
# 1. Job Title: Web Developer
#    Job ID: 11
#    Similarity Score: 0.8355
#
# 2. Job Title: UI Web Designer
#    Job ID: 15
#    Similarity Score: 0.8243
#
# 3. Job Title: Web Designer
#    Job ID: 4
#    Similarity Score: 0.8195
#
# 4. Job Title: Web Developer
#    Job ID: 12
#    Similarity Score: 0.8194
#
# 5. Job Title: SR. Web Designer
#    Job ID: 10
#    Similarity Score: 0.8181
#
# 6. Job Title: Remote Website Designer
#    Job ID: 7
#    Similarity Score: 0.8180
#
# 7. Job Title: Web Designer
#    Job ID: 8
#    Similarity Score: 0.8104
#
# 8. Job Title: Web Developer
#    Job ID: 5
#    Similarity Score: 0.8100
#
# 9. Job Title: Wordpress Web Developer
#    Job ID: 14
#    Similarity Score: 0.8089
#
# 10. Job Title: Web Designer
#    Job ID: 9
#    Similarity Score: 0.8082
#
#
# ==============================
# Top 10 Job Matches for Candidate 2385
# Candidate ID: 16270906, Category: TEACHER
# ==============================
#
# 1. Job Title: Web Designer
#    Job ID: 4
#    Similarity Score: 0.8666
#
# 2. Job Title: SR. Web Designer
#    Job ID: 10
#    Similarity Score: 0.8653
#
# 3. Job Title: Web Developer
#    Job ID: 11
#    Similarity Score: 0.8554
#
# 4. Job Title: Web Developer
#    Job ID: 12
#    Similarity Score: 0.8545
#
# 5. Job Title: Web Designer
#    Job ID: 8
#    Similarity Score: 0.8527
#
# 6. Job Title: UI Web Designer
#    Job ID: 15
#    Similarity Score: 0.8468
#
# 7. Job Title: Sales Specialist
#    Job ID: 1
#    Similarity Score: 0.8439
#
# 8. Job Title: Remote Website Designer
#    Job ID: 7
#    Similarity Score: 0.8425
#
# 9. Job Title: Web Developer
#    Job ID: 5
#    Similarity Score: 0.8415
#
# 10. Job Title: Senior UI Designer
#    Job ID: 13
#    Similarity Score: 0.8395
#
#
# ==============================
# Top 10 Job Matches for Candidate 2386
# Candidate ID: 16820422, Category: TEACHER
# ==============================
#
# 1. Job Title: Web Designer
#    Job ID: 4
#    Similarity Score: 0.8490
#
# 2. Job Title: Web Developer
#    Job ID: 11
#    Similarity Score: 0.8452
#
# 3. Job Title: SR. Web Designer
#    Job ID: 10
#    Similarity Score: 0.8407
#
# 4. Job Title: Web Designer
#    Job ID: 8
#    Similarity Score: 0.8383
#
# 5. Job Title: Web Developer
#    Job ID: 12
#    Similarity Score: 0.8317
#
# 6. Job Title: Web Developer
#    Job ID: 5
#    Similarity Score: 0.8297
#
# 7. Job Title: Remote Website Designer
#    Job ID: 7
#    Similarity Score: 0.8287
#
# 8. Job Title: UI Web Designer
#    Job ID: 15
#    Similarity Score: 0.8287
#
# 9. Job Title: Senior UI Designer
#    Job ID: 13
#    Similarity Score: 0.8274
#
# 10. Job Title: Web Designer
#    Job ID: 9
#    Similarity Score: 0.8213
#
#
# ==============================
# Top 10 Job Matches for Candidate 2387
# Candidate ID: 17311685, Category: TEACHER
# ==============================
#
# 1. Job Title: Wordpress Web Developer
#    Job ID: 14
#    Similarity Score: 0.8018
#
# 2. Job Title: Web Designer
#    Job ID: 4
#    Similarity Score: 0.7874
#
# 3. Job Title: Web Designer
#    Job ID: 8
#    Similarity Score: 0.7832
#
# 4. Job Title: Frontend Web Developer
#    Job ID: 6
#    Similarity Score: 0.7794
#
# 5. Job Title: Web Developer
#    Job ID: 12
#    Similarity Score: 0.7783
#
# 6. Job Title: UI Web Designer
#    Job ID: 15
#    Similarity Score: 0.7752
#
# 7. Job Title: Web Developer
#    Job ID: 5
#    Similarity Score: 0.7743
#
# 8. Job Title: Web Developer
#    Job ID: 11
#    Similarity Score: 0.7729
#
# 9. Job Title: Apple Solutions Consultant
#    Job ID: 2
#    Similarity Score: 0.7693
#
# 10. Job Title: SR. Web Designer
#    Job ID: 10
#    Similarity Score: 0.7681
#
#
# ==============================
# Top 10 Job Matches for Candidate 2388
# Candidate ID: 17481570, Category: TEACHER
# ==============================
#
# 1. Job Title: SR. Web Designer
#    Job ID: 10
#    Similarity Score: 0.9186
#
# 2. Job Title: Web Designer
#    Job ID: 8
#    Similarity Score: 0.9173
#
# 3. Job Title: UI Web Designer
#    Job ID: 15
#    Similarity Score: 0.9141
#
# 4. Job Title: Remote Website Designer
#    Job ID: 7
#    Similarity Score: 0.9128
#
# 5. Job Title: Web Developer
#    Job ID: 12
#    Similarity Score: 0.9085
#
# 6. Job Title: Senior UI Designer
#    Job ID: 13
#    Similarity Score: 0.9021
#
# 7. Job Title: Web Developer
#    Job ID: 11
#    Similarity Score: 0.8979
#
# 8. Job Title: Web Developer
#    Job ID: 5
#    Similarity Score: 0.8968
#
# 9. Job Title: Web Designer
#    Job ID: 4
#    Similarity Score: 0.8966
#
# 10. Job Title: Web Designer
#    Job ID: 9
#    Similarity Score: 0.8922
#
#
# ==============================
# Top 10 Job Matches for Candidate 2389
# Candidate ID: 18001081, Category: TEACHER
# ==============================
#
# 1. Job Title: UI Web Designer
#    Job ID: 15
#    Similarity Score: 0.8448
#
# 2. Job Title: Web Designer
#    Job ID: 8
#    Similarity Score: 0.8441
#
# 3. Job Title: Web Designer
#    Job ID: 4
#    Similarity Score: 0.8435
#
# 4. Job Title: Wordpress Web Developer
#    Job ID: 14
#    Similarity Score: 0.8383
#
# 5. Job Title: Frontend Web Developer
#    Job ID: 6
#    Similarity Score: 0.8349
#
# 6. Job Title: SR. Web Designer
#    Job ID: 10
#    Similarity Score: 0.8341
#
# 7. Job Title: Web Developer
#    Job ID: 12
#    Similarity Score: 0.8337
#
# 8. Job Title: Senior UI Designer
#    Job ID: 13
#    Similarity Score: 0.8300
#
# 9. Job Title: Web Developer
#    Job ID: 5
#    Similarity Score: 0.8276
#
# 10. Job Title: Web Developer
#    Job ID: 11
#    Similarity Score: 0.8239
#
#
# ==============================
# Top 10 Job Matches for Candidate 2390
# Candidate ID: 19302310, Category: TEACHER
# ==============================
#
# 1. Job Title: Wordpress Web Developer
#    Job ID: 14
#    Similarity Score: 0.8191
#
# 2. Job Title: Web Designer
#    Job ID: 4
#    Similarity Score: 0.8117
#
# 3. Job Title: Web Designer
#    Job ID: 8
#    Similarity Score: 0.8061
#
# 4. Job Title: Web Developer
#    Job ID: 11
#    Similarity Score: 0.8037
#
# 5. Job Title: UI Web Designer
#    Job ID: 15
#    Similarity Score: 0.7981
#
# 6. Job Title: SR. Web Designer
#    Job ID: 10
#    Similarity Score: 0.7929
#
# 7. Job Title: Web Developer
#    Job ID: 12
#    Similarity Score: 0.7889
#
# 8. Job Title: Web Developer
#    Job ID: 5
#    Similarity Score: 0.7862
#
# 9. Job Title: Frontend Web Developer
#    Job ID: 6
#    Similarity Score: 0.7848
#
# 10. Job Title: Senior UI Designer
#    Job ID: 13
#    Similarity Score: 0.7831
#
#
# ==============================
# Top 10 Job Matches for Candidate 2391
# Candidate ID: 19464810, Category: TEACHER
# ==============================
#
# 1. Job Title: Wordpress Web Developer
#    Job ID: 14
#    Similarity Score: 0.8827
#
# 2. Job Title: Frontend Web Developer
#    Job ID: 6
#    Similarity Score: 0.8153
#
# 3. Job Title: Web Designer
#    Job ID: 4
#    Similarity Score: 0.8125
#
# 4. Job Title: Web Designer
#    Job ID: 8
#    Similarity Score: 0.8086
#
# 5. Job Title: SR. Web Designer
#    Job ID: 10
#    Similarity Score: 0.8068
#
# 6. Job Title: Web Developer
#    Job ID: 11
#    Similarity Score: 0.8030
#
# 7. Job Title: Web Developer
#    Job ID: 5
#    Similarity Score: 0.8015
#
# 8. Job Title: UI Web Designer
#    Job ID: 15
#    Similarity Score: 0.8004
#
# 9. Job Title: Web Developer
#    Job ID: 12
#    Similarity Score: 0.7904
#
# 10. Job Title: Senior UI Designer
#    Job ID: 13
#    Similarity Score: 0.7878
#
#
# ==============================
# Top 10 Job Matches for Candidate 2392
# Candidate ID: 19556300, Category: TEACHER
# ==============================
#
# 1. Job Title: Web Designer
#    Job ID: 4
#    Similarity Score: 0.8393
#
# 2. Job Title: Web Designer
#    Job ID: 8
#    Similarity Score: 0.8276
#
# 3. Job Title: Web Developer
#    Job ID: 11
#    Similarity Score: 0.8264
#
# 4. Job Title: UI Web Designer
#    Job ID: 15
#    Similarity Score: 0.8230
#
# 5. Job Title: Wordpress Web Developer
#    Job ID: 14
#    Similarity Score: 0.8228
#
# 6. Job Title: SR. Web Designer
#    Job ID: 10
#    Similarity Score: 0.8223
#
# 7. Job Title: Web Developer
#    Job ID: 12
#    Similarity Score: 0.8201
#
# 8. Job Title: Web Developer
#    Job ID: 5
#    Similarity Score: 0.8172
#
# 9. Job Title: Frontend Web Developer
#    Job ID: 6
#    Similarity Score: 0.8119
#
# 10. Job Title: Remote Website Designer
#    Job ID: 7
#    Similarity Score: 0.8108
#
#
# ==============================
# Top 10 Job Matches for Candidate 2393
# Candidate ID: 19786924, Category: TEACHER
# ==============================
#
# 1. Job Title: Web Designer
#    Job ID: 8
#    Similarity Score: 0.8353
#
# 2. Job Title: Wordpress Web Developer
#    Job ID: 14
#    Similarity Score: 0.8312
#
# 3. Job Title: SR. Web Designer
#    Job ID: 10
#    Similarity Score: 0.8305
#
# 4. Job Title: Web Developer
#    Job ID: 12
#    Similarity Score: 0.8300
#
# 5. Job Title: Web Developer
#    Job ID: 5
#    Similarity Score: 0.8294
#
# 6. Job Title: Web Designer
#    Job ID: 4
#    Similarity Score: 0.8275
#
# 7. Job Title: UI Web Designer
#    Job ID: 15
#    Similarity Score: 0.8213
#
# 8. Job Title: Web Developer
#    Job ID: 11
#    Similarity Score: 0.8198
#
# 9. Job Title: Frontend Web Developer
#    Job ID: 6
#    Similarity Score: 0.8135
#
# 10. Job Title: Senior UI Designer
#    Job ID: 13
#    Similarity Score: 0.8133
#
#
# ==============================
# Top 10 Job Matches for Candidate 2394
# Candidate ID: 19918523, Category: TEACHER
# ==============================
#
# 1. Job Title: Wordpress Web Developer
#    Job ID: 14
#    Similarity Score: 0.6999
#
# 2. Job Title: Web Designer
#    Job ID: 4
#    Similarity Score: 0.6905
#
# 3. Job Title: Web Designer
#    Job ID: 8
#    Similarity Score: 0.6751
#
# 4. Job Title: Frontend Web Developer
#    Job ID: 6
#    Similarity Score: 0.6710
#
# 5. Job Title: SR. Web Designer
#    Job ID: 10
#    Similarity Score: 0.6684
#
# 6. Job Title: Apple Solutions Consultant
#    Job ID: 2
#    Similarity Score: 0.6671
#
# 7. Job Title: Web Developer
#    Job ID: 11
#    Similarity Score: 0.6654
#
# 8. Job Title: Web Developer
#    Job ID: 5
#    Similarity Score: 0.6564
#
# 9. Job Title: UI Web Designer
#    Job ID: 15
#    Similarity Score: 0.6559
#
# 10. Job Title: Web Developer
#    Job ID: 12
#    Similarity Score: 0.6525
#
#
# ==============================
# Top 10 Job Matches for Candidate 2395
# Candidate ID: 20230207, Category: TEACHER
# ==============================
#
# 1. Job Title: Frontend Web Developer
#    Job ID: 6
#    Similarity Score: 0.8842
#
# 2. Job Title: Apple Solutions Consultant
#    Job ID: 2
#    Similarity Score: 0.8788
#
# 3. Job Title: UI Web Designer
#    Job ID: 15
#    Similarity Score: 0.8607
#
# 4. Job Title: Web Designer
#    Job ID: 8
#    Similarity Score: 0.8607
#
# 5. Job Title: Web Developer
#    Job ID: 12
#    Similarity Score: 0.8567
#
# 6. Job Title: Web Developer
#    Job ID: 5
#    Similarity Score: 0.8539
#
# 7. Job Title: Senior UI Designer
#    Job ID: 13
#    Similarity Score: 0.8519
#
# 8. Job Title: Web Designer
#    Job ID: 4
#    Similarity Score: 0.8496
#
# 9. Job Title: Licensing Coordinator - Consumer Products
#    Job ID: 3
#    Similarity Score: 0.8385
#
# 10. Job Title: Web Designer
#    Job ID: 9
#    Similarity Score: 0.8370
#
#
# ==============================
# Top 10 Job Matches for Candidate 2396
# Candidate ID: 20399718, Category: TEACHER
# ==============================
#
# 1. Job Title: SR. Web Designer
#    Job ID: 10
#    Similarity Score: 0.8033
#
# 2. Job Title: Web Designer
#    Job ID: 4
#    Similarity Score: 0.7972
#
# 3. Job Title: Web Developer
#    Job ID: 11
#    Similarity Score: 0.7942
#
# 4. Job Title: Web Developer
#    Job ID: 12
#    Similarity Score: 0.7881
#
# 5. Job Title: Web Designer
#    Job ID: 8
#    Similarity Score: 0.7868
#
# 6. Job Title: UI Web Designer
#    Job ID: 15
#    Similarity Score: 0.7832
#
# 7. Job Title: Wordpress Web Developer
#    Job ID: 14
#    Similarity Score: 0.7801
#
# 8. Job Title: Remote Website Designer
#    Job ID: 7
#    Similarity Score: 0.7793
#
# 9. Job Title: Web Developer
#    Job ID: 5
#    Similarity Score: 0.7738
#
# 10. Job Title: Senior UI Designer
#    Job ID: 13
#    Similarity Score: 0.7710
#
#
# ==============================
# Top 10 Job Matches for Candidate 2397
# Candidate ID: 20478831, Category: TEACHER
# ==============================
#
# 1. Job Title: Web Designer
#    Job ID: 4
#    Similarity Score: 0.8460
#
# 2. Job Title: SR. Web Designer
#    Job ID: 10
#    Similarity Score: 0.8409
#
# 3. Job Title: Wordpress Web Developer
#    Job ID: 14
#    Similarity Score: 0.8397
#
# 4. Job Title: Web Designer
#    Job ID: 8
#    Similarity Score: 0.8385
#
# 5. Job Title: Web Developer
#    Job ID: 11
#    Similarity Score: 0.8350
#
# 6. Job Title: UI Web Designer
#    Job ID: 15
#    Similarity Score: 0.8340
#
# 7. Job Title: Web Developer
#    Job ID: 5
#    Similarity Score: 0.8314
#
# 8. Job Title: Web Developer
#    Job ID: 12
#    Similarity Score: 0.8294
#
# 9. Job Title: Frontend Web Developer
#    Job ID: 6
#    Similarity Score: 0.8266
#
# 10. Job Title: Web Designer
#    Job ID: 9
#    Similarity Score: 0.8163
#
#
# ==============================
# Top 10 Job Matches for Candidate 2398
# Candidate ID: 20626794, Category: TEACHER
# ==============================
#
# 1. Job Title: Wordpress Web Developer
#    Job ID: 14
#    Similarity Score: 0.8079
#
# 2. Job Title: Web Designer
#    Job ID: 4
#    Similarity Score: 0.7655
#
# 3. Job Title: Frontend Web Developer
#    Job ID: 6
#    Similarity Score: 0.7629
#
# 4. Job Title: SR. Web Designer
#    Job ID: 10
#    Similarity Score: 0.7534
#
# 5. Job Title: Web Designer
#    Job ID: 8
#    Similarity Score: 0.7486
#
# 6. Job Title: Web Developer
#    Job ID: 5
#    Similarity Score: 0.7460
#
# 7. Job Title: Web Developer
#    Job ID: 12
#    Similarity Score: 0.7388
#
# 8. Job Title: Web Developer
#    Job ID: 11
#    Similarity Score: 0.7365
#
# 9. Job Title: UI Web Designer
#    Job ID: 15
#    Similarity Score: 0.7338
#
# 10. Job Title: Apple Solutions Consultant
#    Job ID: 2
#    Similarity Score: 0.7312
#
#
# ==============================
# Top 10 Job Matches for Candidate 2399
# Candidate ID: 21531811, Category: TEACHER
# ==============================
#
# 1. Job Title: Wordpress Web Developer
#    Job ID: 14
#    Similarity Score: 0.8075
#
# 2. Job Title: Web Designer
#    Job ID: 8
#    Similarity Score: 0.7938
#
# 3. Job Title: Web Developer
#    Job ID: 12
#    Similarity Score: 0.7905
#
# 4. Job Title: Web Designer
#    Job ID: 4
#    Similarity Score: 0.7867
#
# 5. Job Title: Web Developer
#    Job ID: 11
#    Similarity Score: 0.7852
#
# 6. Job Title: UI Web Designer
#    Job ID: 15
#    Similarity Score: 0.7845
#
# 7. Job Title: SR. Web Designer
#    Job ID: 10
#    Similarity Score: 0.7838
#
# 8. Job Title: Web Developer
#    Job ID: 5
#    Similarity Score: 0.7807
#
# 9. Job Title: Frontend Web Developer
#    Job ID: 6
#    Similarity Score: 0.7791
#
# 10. Job Title: Remote Website Designer
#    Job ID: 7
#    Similarity Score: 0.7741
#
#
# ==============================
# Top 10 Job Matches for Candidate 2400
# Candidate ID: 21550454, Category: TEACHER
# ==============================
#
# 1. Job Title: Wordpress Web Developer
#    Job ID: 14
#    Similarity Score: 0.5965
#
# 2. Job Title: Frontend Web Developer
#    Job ID: 6
#    Similarity Score: 0.5856
#
# 3. Job Title: UI Web Designer
#    Job ID: 15
#    Similarity Score: 0.5652
#
# 4. Job Title: SR. Web Designer
#    Job ID: 10
#    Similarity Score: 0.5619
#
# 5. Job Title: Apple Solutions Consultant
#    Job ID: 2
#    Similarity Score: 0.5566
#
# 6. Job Title: Web Developer
#    Job ID: 12
#    Similarity Score: 0.5475
#
# 7. Job Title: Web Designer
#    Job ID: 8
#    Similarity Score: 0.5443
#
# 8. Job Title: Remote Website Designer
#    Job ID: 7
#    Similarity Score: 0.5430
#
# 9. Job Title: Web Designer
#    Job ID: 9
#    Similarity Score: 0.5423
#
# 10. Job Title: Senior UI Designer
#    Job ID: 13
#    Similarity Score: 0.5384
#
#
# ==============================
# Top 10 Job Matches for Candidate 2401
# Candidate ID: 21611212, Category: TEACHER
# ==============================
#
# 1. Job Title: Wordpress Web Developer
#    Job ID: 14
#    Similarity Score: 0.6164
#
# 2. Job Title: Frontend Web Developer
#    Job ID: 6
#    Similarity Score: 0.5780
#
# 3. Job Title: Apple Solutions Consultant
#    Job ID: 2
#    Similarity Score: 0.5760
#
# 4. Job Title: SR. Web Designer
#    Job ID: 10
#    Similarity Score: 0.5678
#
# 5. Job Title: Web Designer
#    Job ID: 8
#    Similarity Score: 0.5622
#
# 6. Job Title: Remote Website Designer
#    Job ID: 7
#    Similarity Score: 0.5574
#
# 7. Job Title: Web Developer
#    Job ID: 12
#    Similarity Score: 0.5574
#
# 8. Job Title: UI Web Designer
#    Job ID: 15
#    Similarity Score: 0.5560
#
# 9. Job Title: Web Developer
#    Job ID: 11
#    Similarity Score: 0.5504
#
# 10. Job Title: Web Designer
#    Job ID: 4
#    Similarity Score: 0.5472
#
#
# ==============================
# Top 10 Job Matches for Candidate 2402
# Candidate ID: 21773106, Category: TEACHER
# ==============================
#
# 1. Job Title: Web Designer
#    Job ID: 4
#    Similarity Score: 0.8327
#
# 2. Job Title: Wordpress Web Developer
#    Job ID: 14
#    Similarity Score: 0.8313
#
# 3. Job Title: UI Web Designer
#    Job ID: 15
#    Similarity Score: 0.8229
#
# 4. Job Title: Frontend Web Developer
#    Job ID: 6
#    Similarity Score: 0.8199
#
# 5. Job Title: Web Designer
#    Job ID: 8
#    Similarity Score: 0.8187
#
# 6. Job Title: Web Developer
#    Job ID: 12
#    Similarity Score: 0.8166
#
# 7. Job Title: Web Developer
#    Job ID: 5
#    Similarity Score: 0.8151
#
# 8. Job Title: Web Developer
#    Job ID: 11
#    Similarity Score: 0.8145
#
# 9. Job Title: SR. Web Designer
#    Job ID: 10
#    Similarity Score: 0.8091
#
# 10. Job Title: Senior UI Designer
#    Job ID: 13
#    Similarity Score: 0.8066
#
#
# ==============================
# Top 10 Job Matches for Candidate 2403
# Candidate ID: 22056333, Category: TEACHER
# ==============================
#
# 1. Job Title: Wordpress Web Developer
#    Job ID: 14
#    Similarity Score: 0.6660
#
# 2. Job Title: Frontend Web Developer
#    Job ID: 6
#    Similarity Score: 0.6326
#
# 3. Job Title: SR. Web Designer
#    Job ID: 10
#    Similarity Score: 0.6230
#
# 4. Job Title: UI Web Designer
#    Job ID: 15
#    Similarity Score: 0.6212
#
# 5. Job Title: Web Designer
#    Job ID: 8
#    Similarity Score: 0.6204
#
# 6. Job Title: Apple Solutions Consultant
#    Job ID: 2
#    Similarity Score: 0.6133
#
# 7. Job Title: Web Designer
#    Job ID: 4
#    Similarity Score: 0.6128
#
# 8. Job Title: Web Developer
#    Job ID: 12
#    Similarity Score: 0.6105
#
# 9. Job Title: Web Developer
#    Job ID: 5
#    Similarity Score: 0.6054
#
# 10. Job Title: Web Developer
#    Job ID: 11
#    Similarity Score: 0.6032
#
#
# ==============================
# Top 10 Job Matches for Candidate 2404
# Candidate ID: 22408666, Category: TEACHER
# ==============================
#
# 1. Job Title: Web Designer
#    Job ID: 4
#    Similarity Score: 0.8735
#
# 2. Job Title: SR. Web Designer
#    Job ID: 10
#    Similarity Score: 0.8658
#
# 3. Job Title: Web Developer
#    Job ID: 11
#    Similarity Score: 0.8603
#
# 4. Job Title: Web Developer
#    Job ID: 5
#    Similarity Score: 0.8523
#
# 5. Job Title: Web Developer
#    Job ID: 12
#    Similarity Score: 0.8516
#
# 6. Job Title: UI Web Designer
#    Job ID: 15
#    Similarity Score: 0.8514
#
# 7. Job Title: Web Designer
#    Job ID: 8
#    Similarity Score: 0.8492
#
# 8. Job Title: Remote Website Designer
#    Job ID: 7
#    Similarity Score: 0.8486
#
# 9. Job Title: Senior UI Designer
#    Job ID: 13
#    Similarity Score: 0.8461
#
# 10. Job Title: Web Designer
#    Job ID: 9
#    Similarity Score: 0.8425
#
#
# ==============================
# Top 10 Job Matches for Candidate 2405
# Candidate ID: 22510753, Category: TEACHER
# ==============================
#
# 1. Job Title: Wordpress Web Developer
#    Job ID: 14
#    Similarity Score: 0.8470
#
# 2. Job Title: Web Designer
#    Job ID: 4
#    Similarity Score: 0.8120
#
# 3. Job Title: Web Developer
#    Job ID: 11
#    Similarity Score: 0.8108
#
# 4. Job Title: Web Developer
#    Job ID: 5
#    Similarity Score: 0.8052
#
# 5. Job Title: UI Web Designer
#    Job ID: 15
#    Similarity Score: 0.8039
#
# 6. Job Title: Web Designer
#    Job ID: 8
#    Similarity Score: 0.8025
#
# 7. Job Title: Frontend Web Developer
#    Job ID: 6
#    Similarity Score: 0.8013
#
# 8. Job Title: Web Developer
#    Job ID: 12
#    Similarity Score: 0.8002
#
# 9. Job Title: SR. Web Designer
#    Job ID: 10
#    Similarity Score: 0.7967
#
# 10. Job Title: Senior UI Designer
#    Job ID: 13
#    Similarity Score: 0.7923
#
#
# ==============================
# Top 10 Job Matches for Candidate 2406
# Candidate ID: 22551979, Category: TEACHER
# ==============================
#
# 1. Job Title: Wordpress Web Developer
#    Job ID: 14
#    Similarity Score: 0.7692
#
# 2. Job Title: Frontend Web Developer
#    Job ID: 6
#    Similarity Score: 0.7352
#
# 3. Job Title: Web Designer
#    Job ID: 4
#    Similarity Score: 0.7292
#
# 4. Job Title: SR. Web Designer
#    Job ID: 10
#    Similarity Score: 0.7279
#
# 5. Job Title: Web Designer
#    Job ID: 8
#    Similarity Score: 0.7168
#
# 6. Job Title: Web Developer
#    Job ID: 5
#    Similarity Score: 0.7164
#
# 7. Job Title: UI Web Designer
#    Job ID: 15
#    Similarity Score: 0.7098
#
# 8. Job Title: Web Developer
#    Job ID: 12
#    Similarity Score: 0.7077
#
# 9. Job Title: Web Developer
#    Job ID: 11
#    Similarity Score: 0.7070
#
# 10. Job Title: Senior UI Designer
#    Job ID: 13
#    Similarity Score: 0.7025
#
#
# ==============================
# Top 10 Job Matches for Candidate 2407
# Candidate ID: 22632070, Category: TEACHER
# ==============================
#
# 1. Job Title: Wordpress Web Developer
#    Job ID: 14
#    Similarity Score: 0.8215
#
# 2. Job Title: UI Web Designer
#    Job ID: 15
#    Similarity Score: 0.7819
#
# 3. Job Title: Frontend Web Developer
#    Job ID: 6
#    Similarity Score: 0.7812
#
# 4. Job Title: Web Designer
#    Job ID: 4
#    Similarity Score: 0.7805
#
# 5. Job Title: Web Developer
#    Job ID: 12
#    Similarity Score: 0.7766
#
# 6. Job Title: Web Developer
#    Job ID: 11
#    Similarity Score: 0.7746
#
# 7. Job Title: Web Designer
#    Job ID: 8
#    Similarity Score: 0.7697
#
# 8. Job Title: Web Developer
#    Job ID: 5
#    Similarity Score: 0.7691
#
# 9. Job Title: SR. Web Designer
#    Job ID: 10
#    Similarity Score: 0.7662
#
# 10. Job Title: Senior UI Designer
#    Job ID: 13
#    Similarity Score: 0.7629
#
#
# ==============================
# Top 10 Job Matches for Candidate 2408
# Candidate ID: 22807104, Category: TEACHER
# ==============================
#
# 1. Job Title: Web Designer
#    Job ID: 4
#    Similarity Score: 0.8515
#
# 2. Job Title: Web Developer
#    Job ID: 5
#    Similarity Score: 0.8494
#
# 3. Job Title: Web Developer
#    Job ID: 11
#    Similarity Score: 0.8488
#
# 4. Job Title: Wordpress Web Developer
#    Job ID: 14
#    Similarity Score: 0.8477
#
# 5. Job Title: Web Developer
#    Job ID: 12
#    Similarity Score: 0.8427
#
# 6. Job Title: SR. Web Designer
#    Job ID: 10
#    Similarity Score: 0.8408
#
# 7. Job Title: UI Web Designer
#    Job ID: 15
#    Similarity Score: 0.8361
#
# 8. Job Title: Web Designer
#    Job ID: 8
#    Similarity Score: 0.8356
#
# 9. Job Title: Web Designer
#    Job ID: 9
#    Similarity Score: 0.8355
#
# 10. Job Title: Remote Website Designer
#    Job ID: 7
#    Similarity Score: 0.8337
#
#
# ==============================
# Top 10 Job Matches for Candidate 2409
# Candidate ID: 22884757, Category: TEACHER
# ==============================
#
# 1. Job Title: Wordpress Web Developer
#    Job ID: 14
#    Similarity Score: 0.8000
#
# 2. Job Title: Frontend Web Developer
#    Job ID: 6
#    Similarity Score: 0.7795
#
# 3. Job Title: Web Designer
#    Job ID: 4
#    Similarity Score: 0.7777
#
# 4. Job Title: UI Web Designer
#    Job ID: 15
#    Similarity Score: 0.7652
#
# 5. Job Title: Web Designer
#    Job ID: 8
#    Similarity Score: 0.7633
#
# 6. Job Title: SR. Web Designer
#    Job ID: 10
#    Similarity Score: 0.7627
#
# 7. Job Title: Senior UI Designer
#    Job ID: 13
#    Similarity Score: 0.7600
#
# 8. Job Title: Sales Specialist
#    Job ID: 1
#    Similarity Score: 0.7581
#
# 9. Job Title: Web Developer
#    Job ID: 5
#    Similarity Score: 0.7574
#
# 10. Job Title: Web Developer
#    Job ID: 12
#    Similarity Score: 0.7570
#
#
# ==============================
# Top 10 Job Matches for Candidate 2410
# Candidate ID: 22968380, Category: TEACHER
# ==============================
#
# 1. Job Title: UI Web Designer
#    Job ID: 15
#    Similarity Score: 0.9086
#
# 2. Job Title: Web Designer
#    Job ID: 8
#    Similarity Score: 0.9047
#
# 3. Job Title: Web Designer
#    Job ID: 4
#    Similarity Score: 0.9032
#
# 4. Job Title: SR. Web Designer
#    Job ID: 10
#    Similarity Score: 0.9003
#
# 5. Job Title: Web Developer
#    Job ID: 12
#    Similarity Score: 0.8997
#
# 6. Job Title: Web Developer
#    Job ID: 5
#    Similarity Score: 0.8948
#
# 7. Job Title: Web Developer
#    Job ID: 11
#    Similarity Score: 0.8944
#
# 8. Job Title: Senior UI Designer
#    Job ID: 13
#    Similarity Score: 0.8887
#
# 9. Job Title: Remote Website Designer
#    Job ID: 7
#    Similarity Score: 0.8848
#
# 10. Job Title: Web Designer
#    Job ID: 9
#    Similarity Score: 0.8796
#
#
# ==============================
# Top 10 Job Matches for Candidate 2411
# Candidate ID: 23398843, Category: TEACHER
# ==============================
#
# 1. Job Title: Wordpress Web Developer
#    Job ID: 14
#    Similarity Score: 0.7599
#
# 2. Job Title: Web Designer
#    Job ID: 8
#    Similarity Score: 0.7593
#
# 3. Job Title: Web Designer
#    Job ID: 4
#    Similarity Score: 0.7573
#
# 4. Job Title: SR. Web Designer
#    Job ID: 10
#    Similarity Score: 0.7510
#
# 5. Job Title: Senior UI Designer
#    Job ID: 13
#    Similarity Score: 0.7475
#
# 6. Job Title: UI Web Designer
#    Job ID: 15
#    Similarity Score: 0.7474
#
# 7. Job Title: Web Developer
#    Job ID: 12
#    Similarity Score: 0.7459
#
# 8. Job Title: Frontend Web Developer
#    Job ID: 6
#    Similarity Score: 0.7418
#
# 9. Job Title: Web Developer
#    Job ID: 11
#    Similarity Score: 0.7389
#
# 10. Job Title: Apple Solutions Consultant
#    Job ID: 2
#    Similarity Score: 0.7381
#
#
# ==============================
# Top 10 Job Matches for Candidate 2412
# Candidate ID: 23628651, Category: TEACHER
# ==============================
#
# 1. Job Title: Web Designer
#    Job ID: 8
#    Similarity Score: 0.9086
#
# 2. Job Title: Web Designer
#    Job ID: 4
#    Similarity Score: 0.9022
#
# 3. Job Title: Frontend Web Developer
#    Job ID: 6
#    Similarity Score: 0.8996
#
# 4. Job Title: UI Web Designer
#    Job ID: 15
#    Similarity Score: 0.8990
#
# 5. Job Title: Apple Solutions Consultant
#    Job ID: 2
#    Similarity Score: 0.8975
#
# 6. Job Title: Web Developer
#    Job ID: 12
#    Similarity Score: 0.8960
#
# 7. Job Title: Senior UI Designer
#    Job ID: 13
#    Similarity Score: 0.8938
#
# 8. Job Title: Web Developer
#    Job ID: 5
#    Similarity Score: 0.8930
#
# 9. Job Title: Web Developer
#    Job ID: 11
#    Similarity Score: 0.8872
#
# 10. Job Title: Sales Specialist
#    Job ID: 1
#    Similarity Score: 0.8845
#
#
# ==============================
# Top 10 Job Matches for Candidate 2413
# Candidate ID: 23939133, Category: TEACHER
# ==============================
#
# 1. Job Title: Web Designer
#    Job ID: 4
#    Similarity Score: 0.8477
#
# 2. Job Title: Web Developer
#    Job ID: 11
#    Similarity Score: 0.8430
#
# 3. Job Title: Wordpress Web Developer
#    Job ID: 14
#    Similarity Score: 0.8417
#
# 4. Job Title: Web Designer
#    Job ID: 8
#    Similarity Score: 0.8409
#
# 5. Job Title: SR. Web Designer
#    Job ID: 10
#    Similarity Score: 0.8408
#
# 6. Job Title: UI Web Designer
#    Job ID: 15
#    Similarity Score: 0.8406
#
# 7. Job Title: Web Developer
#    Job ID: 12
#    Similarity Score: 0.8297
#
# 8. Job Title: Web Developer
#    Job ID: 5
#    Similarity Score: 0.8283
#
# 9. Job Title: Remote Website Designer
#    Job ID: 7
#    Similarity Score: 0.8277
#
# 10. Job Title: Web Designer
#    Job ID: 9
#    Similarity Score: 0.8221
#
#
# ==============================
# Top 10 Job Matches for Candidate 2414
# Candidate ID: 24240349, Category: TEACHER
# ==============================
#
# 1. Job Title: Web Designer
#    Job ID: 4
#    Similarity Score: 0.7981
#
# 2. Job Title: Wordpress Web Developer
#    Job ID: 14
#    Similarity Score: 0.7951
#
# 3. Job Title: Frontend Web Developer
#    Job ID: 6
#    Similarity Score: 0.7876
#
# 4. Job Title: Web Designer
#    Job ID: 8
#    Similarity Score: 0.7782
#
# 5. Job Title: SR. Web Designer
#    Job ID: 10
#    Similarity Score: 0.7731
#
# 6. Job Title: Web Developer
#    Job ID: 5
#    Similarity Score: 0.7696
#
# 7. Job Title: UI Web Designer
#    Job ID: 15
#    Similarity Score: 0.7681
#
# 8. Job Title: Web Developer
#    Job ID: 12
#    Similarity Score: 0.7664
#
# 9. Job Title: Web Developer
#    Job ID: 11
#    Similarity Score: 0.7625
#
# 10. Job Title: Senior UI Designer
#    Job ID: 13
#    Similarity Score: 0.7568
#
#
# ==============================
# Top 10 Job Matches for Candidate 2415
# Candidate ID: 24791126, Category: TEACHER
# ==============================
#
# 1. Job Title: SR. Web Designer
#    Job ID: 10
#    Similarity Score: 0.8113
#
# 2. Job Title: Web Designer
#    Job ID: 4
#    Similarity Score: 0.8015
#
# 3. Job Title: Wordpress Web Developer
#    Job ID: 14
#    Similarity Score: 0.7973
#
# 4. Job Title: UI Web Designer
#    Job ID: 15
#    Similarity Score: 0.7971
#
# 5. Job Title: Web Developer
#    Job ID: 5
#    Similarity Score: 0.7953
#
# 6. Job Title: Web Designer
#    Job ID: 8
#    Similarity Score: 0.7951
#
# 7. Job Title: Senior UI Designer
#    Job ID: 13
#    Similarity Score: 0.7889
#
# 8. Job Title: Web Developer
# ...
#    Job ID: 7
#    Similarity Score: 0.8075
#
#
# ==============================
# Top 10 Job Matches for Candidate 2452
# Candidate ID: 58105060, Category: TEACHER
# ==============================
#
# 1. Job Title: Wordpress Web Developer
#    Job ID: 14
#    Similarity Score: 0.8729
#
# 2. Job Title: Web Designer
#    Job ID: 4
#    Similarity Score: 0.8356
#
# 3. Job Title: Frontend Web Developer
#    Job ID: 6
#    Similarity Score: 0.8330
#
# 4. Job Title: UI Web Designer
#    Job ID: 15
#    Similarity Score: 0.8296
#
# 5. Job Title: Senior UI Designer
#    Job ID: 13
#    Similarity Score: 0.8222
#
# 6. Job Title: SR. Web Designer
#    Job ID: 10
#    Similarity Score: 0.8201
#
# 7. Job Title: Web Developer
#    Job ID: 5
#    Similarity Score: 0.8192
#
# 8. Job Title: Web Designer
#    Job ID: 8
#    Similarity Score: 0.8175
#
# 9. Job Title: Sales Specialist
#    Job ID: 1
#    Similarity Score: 0.8128
#
# 10. Job Title: Web Developer
#    Job ID: 12
#    Similarity Score: 0.8127
#
#
# ==============================
# Top 10 Job Matches for Candidate 2453
# Candidate ID: 58665241, Category: TEACHER
# ==============================
#
# 1. Job Title: Web Designer
#    Job ID: 4
#    Similarity Score: 0.8168
#
# 2. Job Title: SR. Web Designer
#    Job ID: 10
#    Similarity Score: 0.8066
#
# 3. Job Title: UI Web Designer
#    Job ID: 15
#    Similarity Score: 0.8057
#
# 4. Job Title: Web Designer
#    Job ID: 8
#    Similarity Score: 0.8055
#
# 5. Job Title: Web Developer
#    Job ID: 5
#    Similarity Score: 0.8032
#
# 6. Job Title: Wordpress Web Developer
#    Job ID: 14
#    Similarity Score: 0.8031
#
# 7. Job Title: Web Developer
#    Job ID: 12
#    Similarity Score: 0.7980
#
# 8. Job Title: Frontend Web Developer
#    Job ID: 6
#    Similarity Score: 0.7953
#
# 9. Job Title: Web Developer
#    Job ID: 11
#    Similarity Score: 0.7944
#
# 10. Job Title: Senior UI Designer
#    Job ID: 13
#    Similarity Score: 0.7912
#
#
# ==============================
# Top 10 Job Matches for Candidate 2454
# Candidate ID: 58708773, Category: TEACHER
# ==============================
#
# 1. Job Title: Wordpress Web Developer
#    Job ID: 14
#    Similarity Score: 0.8233
#
# 2. Job Title: Apple Solutions Consultant
#    Job ID: 2
#    Similarity Score: 0.7745
#
# 3. Job Title: Frontend Web Developer
#    Job ID: 6
#    Similarity Score: 0.7558
#
# 4. Job Title: UI Web Designer
#    Job ID: 15
#    Similarity Score: 0.7343
#
# 5. Job Title: Web Designer
#    Job ID: 8
#    Similarity Score: 0.7293
#
# 6. Job Title: Web Developer
#    Job ID: 5
#    Similarity Score: 0.7276
#
# 7. Job Title: Web Designer
#    Job ID: 4
#    Similarity Score: 0.7257
#
# 8. Job Title: Senior UI Designer
#    Job ID: 13
#    Similarity Score: 0.7237
#
# 9. Job Title: Web Developer
#    Job ID: 12
#    Similarity Score: 0.7215
#
# 10. Job Title: Remote Website Designer
#    Job ID: 7
#    Similarity Score: 0.7138
#
#
# ==============================
# Top 10 Job Matches for Candidate 2455
# Candidate ID: 62184086, Category: TEACHER
# ==============================
#
# 1. Job Title: Wordpress Web Developer
#    Job ID: 14
#    Similarity Score: 0.7968
#
# 2. Job Title: Web Designer
#    Job ID: 8
#    Similarity Score: 0.7706
#
# 3. Job Title: Frontend Web Developer
#    Job ID: 6
#    Similarity Score: 0.7693
#
# 4. Job Title: Web Developer
#    Job ID: 12
#    Similarity Score: 0.7665
#
# 5. Job Title: UI Web Designer
#    Job ID: 15
#    Similarity Score: 0.7659
#
# 6. Job Title: SR. Web Designer
#    Job ID: 10
#    Similarity Score: 0.7632
#
# 7. Job Title: Web Designer
#    Job ID: 4
#    Similarity Score: 0.7597
#
# 8. Job Title: Web Developer
#    Job ID: 11
#    Similarity Score: 0.7584
#
# 9. Job Title: Web Developer
#    Job ID: 5
#    Similarity Score: 0.7565
#
# 10. Job Title: Remote Website Designer
#    Job ID: 7
#    Similarity Score: 0.7508
#
#
# ==============================
# Top 10 Job Matches for Candidate 2456
# Candidate ID: 63391085, Category: TEACHER
# ==============================
#
# 1. Job Title: Wordpress Web Developer
#    Job ID: 14
#    Similarity Score: 0.8386
#
# 2. Job Title: Web Developer
#    Job ID: 11
#    Similarity Score: 0.8268
#
# 3. Job Title: Web Designer
#    Job ID: 4
#    Similarity Score: 0.8196
#
# 4. Job Title: Web Developer
#    Job ID: 5
#    Similarity Score: 0.8159
#
# 5. Job Title: Web Developer
#    Job ID: 12
#    Similarity Score: 0.8093
#
# 6. Job Title: UI Web Designer
#    Job ID: 15
#    Similarity Score: 0.8065
#
# 7. Job Title: Web Designer
#    Job ID: 9
#    Similarity Score: 0.8046
#
# 8. Job Title: Remote Website Designer
#    Job ID: 7
#    Similarity Score: 0.8034
#
# 9. Job Title: Web Designer
#    Job ID: 8
#    Similarity Score: 0.8009
#
# 10. Job Title: SR. Web Designer
#    Job ID: 10
#    Similarity Score: 0.7952
#
#
# ==============================
# Top 10 Job Matches for Candidate 2457
# Candidate ID: 66683238, Category: TEACHER
# ==============================
#
# 1. Job Title: Wordpress Web Developer
#    Job ID: 14
#    Similarity Score: 0.8536
#
# 2. Job Title: Web Developer
#    Job ID: 11
#    Similarity Score: 0.8468
#
# 3. Job Title: Web Designer
#    Job ID: 4
#    Similarity Score: 0.8449
#
# 4. Job Title: Web Developer
#    Job ID: 12
#    Similarity Score: 0.8387
#
# 5. Job Title: Web Designer
#    Job ID: 9
#    Similarity Score: 0.8377
#
# 6. Job Title: SR. Web Designer
#    Job ID: 10
#    Similarity Score: 0.8368
#
# 7. Job Title: Web Developer
#    Job ID: 5
#    Similarity Score: 0.8361
#
# 8. Job Title: Web Designer
#    Job ID: 8
#    Similarity Score: 0.8352
#
# 9. Job Title: UI Web Designer
#    Job ID: 15
#    Similarity Score: 0.8319
#
# 10. Job Title: Remote Website Designer
#    Job ID: 7
#    Similarity Score: 0.8312
#
#
# ==============================
# Top 10 Job Matches for Candidate 2458
# Candidate ID: 66906212, Category: TEACHER
# ==============================
#
# 1. Job Title: Web Designer
#    Job ID: 8
#    Similarity Score: 0.9041
#
# 2. Job Title: UI Web Designer
#    Job ID: 15
#    Similarity Score: 0.9037
#
# 3. Job Title: SR. Web Designer
#    Job ID: 10
#    Similarity Score: 0.8996
#
# 4. Job Title: Web Designer
#    Job ID: 4
#    Similarity Score: 0.8993
#
# 5. Job Title: Web Developer
#    Job ID: 11
#    Similarity Score: 0.8945
#
# 6. Job Title: Web Developer
#    Job ID: 12
#    Similarity Score: 0.8919
#
# 7. Job Title: Senior UI Designer
#    Job ID: 13
#    Similarity Score: 0.8909
#
# 8. Job Title: Web Developer
#    Job ID: 5
#    Similarity Score: 0.8892
#
# 9. Job Title: Remote Website Designer
#    Job ID: 7
#    Similarity Score: 0.8885
#
# 10. Job Title: Web Designer
#    Job ID: 9
#    Similarity Score: 0.8848
#
#
# ==============================
# Top 10 Job Matches for Candidate 2459
# Candidate ID: 69005326, Category: TEACHER
# ==============================
#
# 1. Job Title: Apple Solutions Consultant
#    Job ID: 2
#    Similarity Score: 0.8680
#
# 2. Job Title: Web Designer
#    Job ID: 8
#    Similarity Score: 0.8501
#
# 3. Job Title: Frontend Web Developer
#    Job ID: 6
#    Similarity Score: 0.8490
#
# 4. Job Title: Web Developer
#    Job ID: 12
#    Similarity Score: 0.8457
#
# 5. Job Title: UI Web Designer
#    Job ID: 15
#    Similarity Score: 0.8442
#
# 6. Job Title: SR. Web Designer
#    Job ID: 10
#    Similarity Score: 0.8408
#
# 7. Job Title: Wordpress Web Developer
#    Job ID: 14
#    Similarity Score: 0.8374
#
# 8. Job Title: Web Developer
#    Job ID: 5
#    Similarity Score: 0.8350
#
# 9. Job Title: Web Designer
#    Job ID: 4
#    Similarity Score: 0.8337
#
# 10. Job Title: Senior UI Designer
#    Job ID: 13
#    Similarity Score: 0.8322
#
#
# ==============================
# Top 10 Job Matches for Candidate 2460
# Candidate ID: 69532425, Category: TEACHER
# ==============================
#
# 1. Job Title: Web Developer
#    Job ID: 5
#    Similarity Score: 0.9039
#
# 2. Job Title: Web Designer
#    Job ID: 8
#    Similarity Score: 0.9033
#
# 3. Job Title: Web Developer
#    Job ID: 12
#    Similarity Score: 0.8984
#
# 4. Job Title: UI Web Designer
#    Job ID: 15
#    Similarity Score: 0.8952
#
# 5. Job Title: Licensing Coordinator - Consumer Products
#    Job ID: 3
#    Similarity Score: 0.8942
#
# 6. Job Title: Remote Website Designer
#    Job ID: 7
#    Similarity Score: 0.8938
#
# 7. Job Title: Frontend Web Developer
#    Job ID: 6
#    Similarity Score: 0.8911
#
# 8. Job Title: Web Designer
#    Job ID: 4
#    Similarity Score: 0.8911
#
# 9. Job Title: SR. Web Designer
#    Job ID: 10
#    Similarity Score: 0.8903
#
# 10. Job Title: Web Developer
#    Job ID: 11
#    Similarity Score: 0.8891
#
#
# ==============================
# Top 10 Job Matches for Candidate 2461
# Candidate ID: 70892619, Category: TEACHER
# ==============================
#
# 1. Job Title: Web Designer
#    Job ID: 4
#    Similarity Score: 0.8556
#
# 2. Job Title: Frontend Web Developer
#    Job ID: 6
#    Similarity Score: 0.8489
#
# 3. Job Title: Web Designer
#    Job ID: 8
#    Similarity Score: 0.8448
#
# 4. Job Title: UI Web Designer
#    Job ID: 15
#    Similarity Score: 0.8429
#
# 5. Job Title: Senior UI Designer
#    Job ID: 13
#    Similarity Score: 0.8360
#
# 6. Job Title: Web Developer
#    Job ID: 5
#    Similarity Score: 0.8350
#
# 7. Job Title: SR. Web Designer
#    Job ID: 10
#    Similarity Score: 0.8335
#
# 8. Job Title: Web Developer
#    Job ID: 12
#    Similarity Score: 0.8328
#
# 9. Job Title: Wordpress Web Developer
#    Job ID: 14
#    Similarity Score: 0.8301
#
# 10. Job Title: Web Developer
#    Job ID: 11
#    Similarity Score: 0.8257
#
#
# ==============================
# Top 10 Job Matches for Candidate 2462
# Candidate ID: 74816727, Category: TEACHER
# ==============================
#
# 1. Job Title: Frontend Web Developer
#    Job ID: 6
#    Similarity Score: 0.8289
#
# 2. Job Title: Wordpress Web Developer
#    Job ID: 14
#    Similarity Score: 0.8276
#
# 3. Job Title: Web Designer
#    Job ID: 4
#    Similarity Score: 0.8250
#
# 4. Job Title: Web Designer
#    Job ID: 8
#    Similarity Score: 0.8148
#
# 5. Job Title: UI Web Designer
#    Job ID: 15
#    Similarity Score: 0.8119
#
# 6. Job Title: Web Developer
#    Job ID: 11
#    Similarity Score: 0.8096
#
# 7. Job Title: Web Developer
#    Job ID: 5
#    Similarity Score: 0.8092
#
# 8. Job Title: Web Developer
#    Job ID: 12
#    Similarity Score: 0.8073
#
# 9. Job Title: SR. Web Designer
#    Job ID: 10
#    Similarity Score: 0.8050
#
# 10. Job Title: Senior UI Designer
#    Job ID: 13
#    Similarity Score: 0.7967
#
#
# ==============================
# Top 10 Job Matches for Candidate 2463
# Candidate ID: 76196367, Category: TEACHER
# ==============================
#
# 1. Job Title: Web Developer
#    Job ID: 11
#    Similarity Score: 0.9461
#
# 2. Job Title: Remote Website Designer
#    Job ID: 7
#    Similarity Score: 0.9423
#
# 3. Job Title: SR. Web Designer
#    Job ID: 10
#    Similarity Score: 0.9421
#
# 4. Job Title: UI Web Designer
#    Job ID: 15
#    Similarity Score: 0.9319
#
# 5. Job Title: Web Designer
#    Job ID: 8
#    Similarity Score: 0.9276
#
# 6. Job Title: Web Designer
#    Job ID: 9
#    Similarity Score: 0.9276
#
# 7. Job Title: Licensing Coordinator - Consumer Products
#    Job ID: 3
#    Similarity Score: 0.9233
#
# 8. Job Title: Web Developer
#    Job ID: 5
#    Similarity Score: 0.9184
#
# 9. Job Title: Web Developer
#    Job ID: 12
#    Similarity Score: 0.9164
#
# 10. Job Title: Senior UI Designer
#    Job ID: 13
#    Similarity Score: 0.9139
#
#
# ==============================
# Top 10 Job Matches for Candidate 2464
# Candidate ID: 79663360, Category: TEACHER
# ==============================
#
# 1. Job Title: Wordpress Web Developer
#    Job ID: 14
#    Similarity Score: 0.8218
#
# 2. Job Title: Frontend Web Developer
#    Job ID: 6
#    Similarity Score: 0.8106
#
# 3. Job Title: SR. Web Designer
#    Job ID: 10
#    Similarity Score: 0.8100
#
# 4. Job Title: Web Designer
#    Job ID: 4
#    Similarity Score: 0.8099
#
# 5. Job Title: Web Designer
#    Job ID: 8
#    Similarity Score: 0.8092
#
# 6. Job Title: Web Developer
#    Job ID: 12
#    Similarity Score: 0.8084
#
# 7. Job Title: UI Web Designer
#    Job ID: 15
#    Similarity Score: 0.8083
#
# 8. Job Title: Web Developer
#    Job ID: 5
#    Similarity Score: 0.8058
#
# 9. Job Title: Apple Solutions Consultant
#    Job ID: 2
#    Similarity Score: 0.8037
#
# 10. Job Title: Web Developer
#    Job ID: 11
#    Similarity Score: 0.8001
#
#
# ==============================
# Top 10 Job Matches for Candidate 2465
# Candidate ID: 86322251, Category: TEACHER
# ==============================
#
# 1. Job Title: Web Designer
#    Job ID: 4
#    Similarity Score: 0.8034
#
# 2. Job Title: Wordpress Web Developer
#    Job ID: 14
#    Similarity Score: 0.7989
#
# 3. Job Title: Web Designer
#    Job ID: 8
#    Similarity Score: 0.7932
#
# 4. Job Title: UI Web Designer
#    Job ID: 15
#    Similarity Score: 0.7917
#
# 5. Job Title: Web Developer
#    Job ID: 11
#    Similarity Score: 0.7906
#
# 6. Job Title: SR. Web Designer
#    Job ID: 10
#    Similarity Score: 0.7894
#
# 7. Job Title: Frontend Web Developer
#    Job ID: 6
#    Similarity Score: 0.7822
#
# 8. Job Title: Apple Solutions Consultant
#    Job ID: 2
#    Similarity Score: 0.7821
#
# 9. Job Title: Senior UI Designer
#    Job ID: 13
#    Similarity Score: 0.7798
#
# 10. Job Title: Web Developer
#    Job ID: 12
#    Similarity Score: 0.7797
#
#
# ==============================
# Top 10 Job Matches for Candidate 2466
# Candidate ID: 86597425, Category: TEACHER
# ==============================
#
# 1. Job Title: SR. Web Designer
#    Job ID: 10
#    Similarity Score: 0.8761
#
# 2. Job Title: Web Developer
#    Job ID: 11
#    Similarity Score: 0.8725
#
# 3. Job Title: Web Designer
#    Job ID: 4
#    Similarity Score: 0.8626
#
# 4. Job Title: Web Developer
#    Job ID: 5
#    Similarity Score: 0.8607
#
# 5. Job Title: Wordpress Web Developer
#    Job ID: 14
#    Similarity Score: 0.8606
#
# 6. Job Title: Web Designer
#    Job ID: 8
#    Similarity Score: 0.8584
#
# 7. Job Title: Web Developer
#    Job ID: 12
#    Similarity Score: 0.8529
#
# 8. Job Title: UI Web Designer
#    Job ID: 15
#    Similarity Score: 0.8512
#
# 9. Job Title: Remote Website Designer
#    Job ID: 7
#    Similarity Score: 0.8455
#
# 10. Job Title: Licensing Coordinator - Consumer Products
#    Job ID: 3
#    Similarity Score: 0.8405
#
#
# ==============================
# Top 10 Job Matches for Candidate 2467
# Candidate ID: 90363254, Category: TEACHER
# ==============================
#
# 1. Job Title: UI Web Designer
#    Job ID: 15
#    Similarity Score: 0.8891
#
# 2. Job Title: Senior UI Designer
#    Job ID: 13
#    Similarity Score: 0.8843
#
# 3. Job Title: Web Designer
#    Job ID: 4
#    Similarity Score: 0.8841
#
# 4. Job Title: Web Designer
#    Job ID: 8
#    Similarity Score: 0.8841
#
# 5. Job Title: Web Developer
#    Job ID: 11
#    Similarity Score: 0.8832
#
# 6. Job Title: Remote Website Designer
#    Job ID: 7
#    Similarity Score: 0.8828
#
# 7. Job Title: SR. Web Designer
#    Job ID: 10
#    Similarity Score: 0.8814
#
# 8. Job Title: Wordpress Web Developer
#    Job ID: 14
#    Similarity Score: 0.8783
#
# 9. Job Title: Web Designer
#    Job ID: 9
#    Similarity Score: 0.8758
#
# 10. Job Title: Web Developer
#    Job ID: 5
#    Similarity Score: 0.8735
#
#
# ==============================
# Top 10 Job Matches for Candidate 2468
# Candidate ID: 96547039, Category: TEACHER
# ==============================
#
# 1. Job Title: Wordpress Web Developer
#    Job ID: 14
#    Similarity Score: 0.8252
#
# 2. Job Title: Frontend Web Developer
#    Job ID: 6
#    Similarity Score: 0.7953
#
# 3. Job Title: Web Designer
#    Job ID: 8
#    Similarity Score: 0.7896
#
# 4. Job Title: Web Developer
#    Job ID: 12
#    Similarity Score: 0.7893
#
# 5. Job Title: Apple Solutions Consultant
#    Job ID: 2
#    Similarity Score: 0.7884
#
# 6. Job Title: UI Web Designer
#    Job ID: 15
#    Similarity Score: 0.7842
#
# 7. Job Title: Web Designer
#    Job ID: 4
#    Similarity Score: 0.7823
#
# 8. Job Title: Web Developer
#    Job ID: 5
#    Similarity Score: 0.7783
#
# 9. Job Title: Web Designer
#    Job ID: 9
#    Similarity Score: 0.7765
#
# 10. Job Title: Web Developer
#    Job ID: 11
#    Similarity Score: 0.7744
#
#
# ==============================
# Top 10 Job Matches for Candidate 2469
# Candidate ID: 99244405, Category: TEACHER
# ==============================
#
# 1. Job Title: Wordpress Web Developer
#    Job ID: 14
#    Similarity Score: 0.6814
#
# 2. Job Title: Apple Solutions Consultant
#    Job ID: 2
#    Similarity Score: 0.6784
#
# 3. Job Title: Web Designer
#    Job ID: 8
#    Similarity Score: 0.6460
#
# 4. Job Title: UI Web Designer
#    Job ID: 15
#    Similarity Score: 0.6449
#
# 5. Job Title: Remote Website Designer
#    Job ID: 7
#    Similarity Score: 0.6423
#
# 6. Job Title: Frontend Web Developer
#    Job ID: 6
#    Similarity Score: 0.6415
#
# 7. Job Title: Web Developer
#    Job ID: 11
#    Similarity Score: 0.6382
#
# 8. Job Title: Senior UI Designer
#    Job ID: 13
#    Similarity Score: 0.6346
#
# 9. Job Title: Web Designer
#    Job ID: 4
#    Similarity Score: 0.6311
#
# 10. Job Title: SR. Web Designer
#    Job ID: 10
#    Similarity Score: 0.6289

# %%
# Rank candidates for each job description based on similarity scores
num_top_candidates = 5
top_candidates = []

for i, job_description in enumerate(job_descriptions):
    candidates_with_scores = list(enumerate(similarity_scores[i]))
    candidates_with_scores.sort(key=lambda x: x[1], reverse=True)
    top_candidates_for_job = candidates_with_scores[:num_top_candidates]
    top_candidates.append(top_candidates_for_job)

# Print the top candidates for each job description
for i, job_description in enumerate(job_descriptions):
    job_title = jd_df['position_title'][i]

    print(f"\n==============================")
    print(f"Top Candidates for Job Description {i + 1}")
    print(f"Position: {job_title}")
    print("==============================\n")

    for rank, (candidate_index, score) in enumerate(top_candidates[i], start=1):
        candidate_id = cv_df['ID'][candidate_index]
        candidate_category = cv_df['Category'][candidate_index]

        print(f"{rank}. Candidate {candidate_index + 1}")
        print(f"   Similarity Score: {score:.4f}")
        print(f"   Candidate ID: {candidate_id}, Category: {candidate_category}")
        print(f"   Resume Link: {candidate_category}/{candidate_id}.pdf\n")
# Out:
# ==============================
# Top Candidates for Job Description 1
# Position: Sales Specialist
# ==============================
#
# 1. Candidate 1949
#    Similarity Score: 0.9415
#    Candidate ID: 18827609, Category: HR
#    Resume Link: HR/18827609.pdf
#
# 2. Candidate 291
#    Similarity Score: 0.9388
#    Candidate ID: 62994611, Category: AGRICULTURE
#    Resume Link: AGRICULTURE/62994611.pdf
#
# 3. Candidate 478
#    Similarity Score: 0.9387
#    Candidate ID: 43622023, Category: ARTS
#    Resume Link: ARTS/43622023.pdf
#
# 4. Candidate 28
#    Similarity Score: 0.9377
#    Candidate ID: 16237710, Category: ACCOUNTANT
#    Resume Link: ACCOUNTANT/16237710.pdf
#
# 5. Candidate 1803
#    Similarity Score: 0.9314
#    Candidate ID: 10466208, Category: HEALTHCARE
#    Resume Link: HEALTHCARE/10466208.pdf
#
#
# ==============================
# Top Candidates for Job Description 2
# Position: Apple Solutions Consultant
# ==============================
#
# 1. Candidate 168
#    Similarity Score: 0.9236
#    Candidate ID: 22391901, Category: ADVOCATE
#    Resume Link: ADVOCATE/22391901.pdf
#
# 2. Candidate 904
#    Similarity Score: 0.9165
#    Candidate ID: 95382114, Category: BUSINESS-DEVELOPMENT
#    Resume Link: BUSINESS-DEVELOPMENT/95382114.pdf
#
# 3. Candidate 1730
#    Similarity Score: 0.9159
#    Candidate ID: 21238396, Category: FITNESS
#    Resume Link: FITNESS/21238396.pdf
#
# 4. Candidate 952
#    Similarity Score: 0.9155
#    Candidate ID: 21869994, Category: CHEF
#    Resume Link: CHEF/21869994.pdf
#
# 5. Candidate 482
#    Similarity Score: 0.9146
#    Candidate ID: 54100393, Category: ARTS
#    Resume Link: ARTS/54100393.pdf
#
#
# ==============================
# Top Candidates for Job Description 3
# Position: Licensing Coordinator - Consumer Products
# ==============================
#
# 1. Candidate 478
#    Similarity Score: 0.9598
#    Candidate ID: 43622023, Category: ARTS
#    Resume Link: ARTS/43622023.pdf
#
# 2. Candidate 2153
#    Similarity Score: 0.9496
#    Candidate ID: 12237267, Category: PUBLIC-RELATIONS
#    Resume Link: PUBLIC-RELATIONS/12237267.pdf
#
# 3. Candidate 1189
#    Similarity Score: 0.9458
#    Candidate ID: 26234972, Category: CONSULTANT
#    Resume Link: CONSULTANT/26234972.pdf
#
# 4. Candidate 2271
#    Similarity Score: 0.9440
#    Candidate ID: 15620421, Category: SALES
#    Resume Link: SALES/15620421.pdf
#
# 5. Candidate 1803
#    Similarity Score: 0.9428
#    Candidate ID: 10466208, Category: HEALTHCARE
#    Resume Link: HEALTHCARE/10466208.pdf
#
#
# ==============================
# Top Candidates for Job Description 4
# Position: Web Designer
# ==============================
#
# 1. Candidate 1279
#    Similarity Score: 0.9487
#    Candidate ID: 18979238, Category: DESIGNER
#    Resume Link: DESIGNER/18979238.pdf
#
# 2. Candidate 1949
#    Similarity Score: 0.9438
#    Candidate ID: 18827609, Category: HR
#    Resume Link: HR/18827609.pdf
#
# 3. Candidate 478
#    Similarity Score: 0.9380
#    Candidate ID: 43622023, Category: ARTS
#    Resume Link: ARTS/43622023.pdf
#
# 4. Candidate 1009
#    Similarity Score: 0.9357
#    Candidate ID: 53265899, Category: CHEF
#    Resume Link: CHEF/53265899.pdf
#
# 5. Candidate 2444
#    Similarity Score: 0.9341
#    Candidate ID: 37660306, Category: TEACHER
#    Resume Link: TEACHER/37660306.pdf
#
#
# ==============================
# Top Candidates for Job Description 5
# Position: Web Developer
# ==============================
#
# 1. Candidate 291
#    Similarity Score: 0.9501
#    Candidate ID: 62994611, Category: AGRICULTURE
#    Resume Link: AGRICULTURE/62994611.pdf
#
# 2. Candidate 478
#    Similarity Score: 0.9465
#    Candidate ID: 43622023, Category: ARTS
#    Resume Link: ARTS/43622023.pdf
#
# 3. Candidate 1279
#    Similarity Score: 0.9446
#    Candidate ID: 18979238, Category: DESIGNER
#    Resume Link: DESIGNER/18979238.pdf
#
# 4. Candidate 1368
#    Similarity Score: 0.9408
#    Candidate ID: 14761906, Category: DIGITAL-MEDIA
#    Resume Link: DIGITAL-MEDIA/14761906.pdf
#
# 5. Candidate 1949
#    Similarity Score: 0.9378
#    Candidate ID: 18827609, Category: HR
#    Resume Link: HR/18827609.pdf
#
#
# ==============================
# Top Candidates for Job Description 6
# Position: Frontend Web Developer
# ==============================
#
# 1. Candidate 1327
#    Similarity Score: 0.9255
#    Candidate ID: 36269672, Category: DESIGNER
#    Resume Link: DESIGNER/36269672.pdf
#
# 2. Candidate 1730
#    Similarity Score: 0.9244
#    Candidate ID: 21238396, Category: FITNESS
#    Resume Link: FITNESS/21238396.pdf
#
# 3. Candidate 1358
#    Similarity Score: 0.9191
#    Candidate ID: 11270462, Category: DIGITAL-MEDIA
#    Resume Link: DIGITAL-MEDIA/11270462.pdf
#
# 4. Candidate 2254
#    Similarity Score: 0.9169
#    Candidate ID: 10464113, Category: SALES
#    Resume Link: SALES/10464113.pdf
#
# 5. Candidate 482
#    Similarity Score: 0.9167
#    Candidate ID: 54100393, Category: ARTS
#    Resume Link: ARTS/54100393.pdf
#
#
# ==============================
# Top Candidates for Job Description 7
# Position: Remote Website Designer
# ==============================
#
# 1. Candidate 478
#    Similarity Score: 0.9613
#    Candidate ID: 43622023, Category: ARTS
#    Resume Link: ARTS/43622023.pdf
#
# 2. Candidate 1949
#    Similarity Score: 0.9590
#    Candidate ID: 18827609, Category: HR
#    Resume Link: HR/18827609.pdf
#
# 3. Candidate 2153
#    Similarity Score: 0.9581
#    Candidate ID: 12237267, Category: PUBLIC-RELATIONS
#    Resume Link: PUBLIC-RELATIONS/12237267.pdf
#
# 4. Candidate 1979
#    Similarity Score: 0.9579
#    Candidate ID: 27165830, Category: HR
#    Resume Link: HR/27165830.pdf
#
# 5. Candidate 291
#    Similarity Score: 0.9574
#    Candidate ID: 62994611, Category: AGRICULTURE
#    Resume Link: AGRICULTURE/62994611.pdf
#
#
# ==============================
# Top Candidates for Job Description 8
# Position: Web Designer
# ==============================
#
# 1. Candidate 478
#    Similarity Score: 0.9577
#    Candidate ID: 43622023, Category: ARTS
#    Resume Link: ARTS/43622023.pdf
#
# 2. Candidate 1949
#    Similarity Score: 0.9530
#    Candidate ID: 18827609, Category: HR
#    Resume Link: HR/18827609.pdf
#
# 3. Candidate 2153
#    Similarity Score: 0.9480
#    Candidate ID: 12237267, Category: PUBLIC-RELATIONS
#    Resume Link: PUBLIC-RELATIONS/12237267.pdf
#
# 4. Candidate 1960
#    Similarity Score: 0.9478
#    Candidate ID: 21830565, Category: HR
#    Resume Link: HR/21830565.pdf
#
# 5. Candidate 482
#    Similarity Score: 0.9469
#    Candidate ID: 54100393, Category: ARTS
#    Resume Link: ARTS/54100393.pdf
#
#
# ==============================
# Top Candidates for Job Description 9
# Position: Web Designer
# ==============================
#
# 1. Candidate 291
#    Similarity Score: 0.9542
#    Candidate ID: 62994611, Category: AGRICULTURE
#    Resume Link: AGRICULTURE/62994611.pdf
#
# 2. Candidate 1949
#    Similarity Score: 0.9494
#    Candidate ID: 18827609, Category: HR
#    Resume Link: HR/18827609.pdf
#
# 3. Candidate 478
#    Similarity Score: 0.9493
#    Candidate ID: 43622023, Category: ARTS
#    Resume Link: ARTS/43622023.pdf
#
# 4. Candidate 1155
#    Similarity Score: 0.9447
#    Candidate ID: 15119529, Category: CONSULTANT
#    Resume Link: CONSULTANT/15119529.pdf
#
# 5. Candidate 2172
#    Similarity Score: 0.9434
#    Candidate ID: 16620172, Category: PUBLIC-RELATIONS
#    Resume Link: PUBLIC-RELATIONS/16620172.pdf
#
#
# ==============================
# Top Candidates for Job Description 10
# Position: SR. Web Designer
# ==============================
#
# 1. Candidate 1562
#    Similarity Score: 0.9600
#    Candidate ID: 82125182, Category: ENGINEERING
#    Resume Link: ENGINEERING/82125182.pdf
#
# 2. Candidate 291
#    Similarity Score: 0.9570
#    Candidate ID: 62994611, Category: AGRICULTURE
#    Resume Link: AGRICULTURE/62994611.pdf
#
# 3. Candidate 1960
#    Similarity Score: 0.9540
#    Candidate ID: 21830565, Category: HR
#    Resume Link: HR/21830565.pdf
#
# 4. Candidate 1979
#    Similarity Score: 0.9518
#    Candidate ID: 27165830, Category: HR
#    Resume Link: HR/27165830.pdf
#
# 5. Candidate 1949
#    Similarity Score: 0.9490
#    Candidate ID: 18827609, Category: HR
#    Resume Link: HR/18827609.pdf
#
#
# ==============================
# Top Candidates for Job Description 11
# Position: Web Developer
# ==============================
#
# 1. Candidate 1949
#    Similarity Score: 0.9611
#    Candidate ID: 18827609, Category: HR
#    Resume Link: HR/18827609.pdf
#
# 2. Candidate 291
#    Similarity Score: 0.9564
#    Candidate ID: 62994611, Category: AGRICULTURE
#    Resume Link: AGRICULTURE/62994611.pdf
#
# 3. Candidate 1155
#    Similarity Score: 0.9562
#    Candidate ID: 15119529, Category: CONSULTANT
#    Resume Link: CONSULTANT/15119529.pdf
#
# 4. Candidate 2153
#    Similarity Score: 0.9556
#    Candidate ID: 12237267, Category: PUBLIC-RELATIONS
#    Resume Link: PUBLIC-RELATIONS/12237267.pdf
#
# 5. Candidate 2299
#    Similarity Score: 0.9531
#    Candidate ID: 22319662, Category: SALES
#    Resume Link: SALES/22319662.pdf
#
#
# ==============================
# Top Candidates for Job Description 12
# Position: Web Developer
# ==============================
#
# 1. Candidate 478
#    Similarity Score: 0.9592
#    Candidate ID: 43622023, Category: ARTS
#    Resume Link: ARTS/43622023.pdf
#
# 2. Candidate 465
#    Similarity Score: 0.9465
#    Candidate ID: 34146825, Category: ARTS
#    Resume Link: ARTS/34146825.pdf
#
# 3. Candidate 1279
#    Similarity Score: 0.9449
#    Candidate ID: 18979238, Category: DESIGNER
#    Resume Link: DESIGNER/18979238.pdf
#
# 4. Candidate 291
#    Similarity Score: 0.9448
#    Candidate ID: 62994611, Category: AGRICULTURE
#    Resume Link: AGRICULTURE/62994611.pdf
#
# 5. Candidate 1949
#    Similarity Score: 0.9433
#    Candidate ID: 18827609, Category: HR
#    Resume Link: HR/18827609.pdf
#
#
# ==============================
# Top Candidates for Job Description 13
# Position: Senior UI Designer
# ==============================
#
# 1. Candidate 478
#    Similarity Score: 0.9459
#    Candidate ID: 43622023, Category: ARTS
#    Resume Link: ARTS/43622023.pdf
#
# 2. Candidate 1279
#    Similarity Score: 0.9446
#    Candidate ID: 18979238, Category: DESIGNER
#    Resume Link: DESIGNER/18979238.pdf
#
# 3. Candidate 1949
#    Similarity Score: 0.9428
#    Candidate ID: 18827609, Category: HR
#    Resume Link: HR/18827609.pdf
#
# 4. Candidate 291
#    Similarity Score: 0.9390
#    Candidate ID: 62994611, Category: AGRICULTURE
#    Resume Link: AGRICULTURE/62994611.pdf
#
# 5. Candidate 1327
#    Similarity Score: 0.9375
#    Candidate ID: 36269672, Category: DESIGNER
#    Resume Link: DESIGNER/36269672.pdf
#
#
# ==============================
# Top Candidates for Job Description 14
# Position: Wordpress Web Developer
# ==============================
#
# 1. Candidate 1307
#    Similarity Score: 0.9450
#    Candidate ID: 26790545, Category: DESIGNER
#    Resume Link: DESIGNER/26790545.pdf
#
# 2. Candidate 2091
#    Similarity Score: 0.9286
#    Candidate ID: 26768723, Category: INFORMATION-TECHNOLOGY
#    Resume Link: INFORMATION-TECHNOLOGY/26768723.pdf
#
# 3. Candidate 1231
#    Similarity Score: 0.9286
#    Candidate ID: 65062795, Category: CONSULTANT
#    Resume Link: CONSULTANT/65062795.pdf
#
# 4. Candidate 1416
#    Similarity Score: 0.9174
#    Candidate ID: 27981289, Category: DIGITAL-MEDIA
#    Resume Link: DIGITAL-MEDIA/27981289.pdf
#
# 5. Candidate 238
#    Similarity Score: 0.9129
#    Candidate ID: 11676151, Category: AGRICULTURE
#    Resume Link: AGRICULTURE/11676151.pdf
#
#
# ==============================
# Top Candidates for Job Description 15
# Position: UI Web Designer
# ==============================
#
# 1. Candidate 482
#    Similarity Score: 0.9563
#    Candidate ID: 54100393, Category: ARTS
#    Resume Link: ARTS/54100393.pdf
#
# 2. Candidate 478
#    Similarity Score: 0.9542
#    Candidate ID: 43622023, Category: ARTS
#    Resume Link: ARTS/43622023.pdf
#
# 3. Candidate 1279
#    Similarity Score: 0.9516
#    Candidate ID: 18979238, Category: DESIGNER
#    Resume Link: DESIGNER/18979238.pdf
#
# 4. Candidate 291
#    Similarity Score: 0.9499
#    Candidate ID: 62994611, Category: AGRICULTURE
#    Resume Link: AGRICULTURE/62994611.pdf
#
# 5. Candidate 402
#    Similarity Score: 0.9469
#    Candidate ID: 12413512, Category: ARTS
#    Resume Link: ARTS/12413512.pdf
